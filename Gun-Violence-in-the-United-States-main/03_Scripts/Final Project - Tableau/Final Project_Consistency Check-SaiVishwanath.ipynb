# %% [markdown]
# # 6.7 Final Project: Tableau Dashboards and Final Analysis

# %% [markdown]
# ## About this notebook

# %% [markdown]
# This notebook contains a final iteration of all the techniques and methodologies practiced in this achievement. This iteration introduces suplementary datasets to delve deeper into the observations made throughout the case study. The datasets include an index of gun law strength and gun violence by Everytown, a non-governmental research organization in the United States focused on gun violence prevention, and population densities at state and county granularity.

# %% [markdown]
# The objective of this notebook is to re-perform exploratory analysis, geographic visualization, linear regression and cluster analysis.

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### This script contains

# %% [markdown]
# ##### 1. Import of libraries and data
# ##### 2. Data cleaning
# ##### 3. Data wrangling

# %% [markdown]
# ####  1. Import of libraries and data

# %%
import pandas as pd
import numpy as np
import os
import json
import geojson

# %%
#Ensuring matplotlib display 
# %matplotlib inline

# %%
#Importing files
path = r'C:/Users/C SaiVishwanath/Documents/CF/Data Immersion/Achievement 6'

# %%
df = pd.read_csv(os.path.join(path, '02_Data', 'Prepared', '130425_mass_shoot_merged_derived_ver3.csv'), index_col = False, encoding='latin1')
df_gunindex = pd.read_csv(os.path.join(path, '02_Data', 'Original', 'Gun Safety Indicators.csv'), sep= ';', index_col = False)
df_popdenstate = pd.read_csv(os.path.join(path, '02_Data', 'Original', 'Population-Density By State.csv'), index_col = False)
df_popdencounty = pd.read_csv(os.path.join(path, '02_Data', 'Original', 'counties_pop density.csv'), index_col = False) 
county_geo = r'C:/Users/C SaiVishwanath/Documents/CF/Data Immersion/Achievement 6/02_Data/Original/counties.geojson'

# %% [markdown]
# #### 2. Data cleaning

# %% [markdown]
# #### Main dataframe

# %%
df.head()
# Out:
#    Incident_ID        Date  Year  Month      State     City  Victims_Killed  \
# 0      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 1      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 2      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 3      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 4      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
#
#    Victims_Injured  Suspects_Killed  Suspects_Injured  ...  State_ID  \
# 0                5                0                 0  ...        TN
# 1                5                0                 0  ...        FL
# 2                5                0                 0  ...        TX
# 3                5                0                 0  ...        MO
# 4                5                0                 0  ...        MI
#
#      State_y    County      Lat      Long Population Shootings_County  \
# 0  Tennessee    Shelby  35.1087  -89.9663        0.0                3
# 1    Florida   Manatee  27.5435  -82.5608        0.0                3
# 2      Texas      Hall  34.7268 -100.5416        0.0                3
# 3   Missouri  Scotland  40.4613  -92.1704        0.0                3
# 4   Michigan    Macomb  42.8956  -82.7689        0.0                3
#
#   Shootings_State  Total_Harmed_Victims  Any_Suspect_Arrested
# 0              30                     6                    No
# 1              30                     6                    No
# 2              30                     6                    No
# 3              30                     6                    No
# 4              30                     6                    No
#
# [5 rows x 25 columns]

# %%
#Missing values check
df.isnull().sum()
# Out:
# Incident_ID             0
# Date                    0
# Year                    0
# Month                   0
# State                   0
# City                    0
# Victims_Killed          0
# Victims_Injured         0
# Suspects_Killed         0
# Suspects_Injured        0
# Suspects_Arrested       0
# Year_Month_State        0
# Handguns_Sold           0
# Long_Guns_Sold          0
# Total_Guns_Sold         0
# State_ID                0
# State_y                 0
# County                  0
# Lat                     0
# Long                    0
# Population              0
# Shootings_County        0
# Shootings_State         0
# Total_Harmed_Victims    0
# Any_Suspect_Arrested    0
# dtype: int64

# %%
#Duplicates check
dups = df.duplicated()
dups.sum()
# Out:
# 16157

# %%
pd.set_option('display.max_columns', None)

# %%
df[df.duplicated()]
# Out:
#        Incident_ID        Date  Year  Month      State      City  \
# 39462      1582816  2019-12-29  2019     12   Illinois  Danville
# 39463      1582816  2019-12-29  2019     12   Illinois  Danville
# 39464      1582816  2019-12-29  2019     12   Illinois  Danville
# 39465      1582816  2019-12-29  2019     12   Illinois  Danville
# 39466      1582816  2019-12-29  2019     12   Illinois  Danville
# ...            ...         ...   ...    ...        ...       ...
# 64516       272016  2015-01-01  2015      1  Tennessee   Memphis
# 64517       272016  2015-01-01  2015      1  Tennessee   Memphis
# 64518       272016  2015-01-01  2015      1  Tennessee   Memphis
# 64519       272016  2015-01-01  2015      1  Tennessee   Memphis
# 64520       272016  2015-01-01  2015      1  Tennessee   Memphis
#
#        Victims_Killed  Victims_Injured  Suspects_Killed  Suspects_Injured  \
# 39462               0                5                0                 0
# 39463               0                5                0                 0
# 39464               0                5                0                 0
# 39465               0                5                0                 0
# 39466               0                5                0                 0
# ...               ...              ...              ...               ...
# 64516               0                5                0                 0
# 64517               0                5                0                 0
# 64518               0                5                0                 0
# 64519               0                5                0                 0
# 64520               0                5                0                 0
#
#        Suspects_Arrested  Year_Month_State  Handguns_Sold  Long_Guns_Sold  \
# 39462                  0  2019-12-Illinois        28489.0         15802.0
# 39463                  0  2019-12-Illinois        28489.0         15802.0
# 39464                  0  2019-12-Illinois        28489.0         15802.0
# 39465                  0  2019-12-Illinois        28489.0         15802.0
# 39466                  0  2019-12-Illinois        28489.0         15802.0
# ...                  ...               ...            ...             ...
# 64516                  2  2015-1-Tennessee        25484.0         17575.0
# 64517                  2  2015-1-Tennessee        25484.0         17575.0
# 64518                  2  2015-1-Tennessee        25484.0         17575.0
# 64519                  2  2015-1-Tennessee        25484.0         17575.0
# 64520                  2  2015-1-Tennessee        25484.0         17575.0
#
#        Total_Guns_Sold State_ID    State_y  County      Lat     Long  \
# 39462          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# 39463          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# 39464          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# 39465          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# 39466          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# ...                ...      ...        ...     ...      ...      ...
# 64516          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
# 64517          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
# 64518          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
# 64519          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
# 64520          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
#
#        Population  Shootings_County  Shootings_State  Total_Harmed_Victims  \
# 39462     49669.0                 9              333                     5
# 39463     49669.0                 9              333                     5
# 39464     49669.0                 9              333                     5
# 39465     49669.0                 9              333                     5
# 39466     49669.0                 9              333                     5
# ...           ...               ...              ...                   ...
# 64516    937598.0                27              386                     5
# 64517    937598.0                27              386                     5
# 64518    937598.0                27              386                     5
# 64519    937598.0                27              386                     5
# 64520    937598.0                27              386                     5
#
#       Any_Suspect_Arrested
# 39462                   No
# 39463                   No
# 39464                   No
# 39465                   No
# 39466                   No
# ...                    ...
# 64516                  Yes
# 64517                  Yes
# 64518                  Yes
# 64519                  Yes
# 64520                  Yes
#
# [16157 rows x 25 columns]

# %%
#Dropping duplicates
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Incident_ID, Date, Year, Month, State, City, Victims_Killed, Victims_Injured, Suspects_Killed, Suspects_Injured, Suspects_Arrested, Year_Month_State, Handguns_Sold, Long_Guns_Sold, Total_Guns_Sold, State_ID, State_y, County, Lat, Long, Population, Shootings_County, Shootings_State, Total_Harmed_Victims, Any_Suspect_Arrested]
# Index: []

# %%
df.shape
# Out:
# (48371, 25)

# %%
df.dtypes
# Out:
# Incident_ID               int64
# Date                     object
# Year                      int64
# Month                     int64
# State                    object
# City                     object
# Victims_Killed            int64
# Victims_Injured           int64
# Suspects_Killed           int64
# Suspects_Injured          int64
# Suspects_Arrested         int64
# Year_Month_State         object
# Handguns_Sold           float64
# Long_Guns_Sold          float64
# Total_Guns_Sold         float64
# State_ID                 object
# State_y                  object
# County                   object
# Lat                     float64
# Long                    float64
# Population              float64
# Shootings_County          int64
# Shootings_State           int64
# Total_Harmed_Victims      int64
# Any_Suspect_Arrested     object
# dtype: object

# %%
df.describe()
# Out:
#         Incident_ID          Year         Month  Victims_Killed  \
# count  4.837100e+04  48371.000000  48371.000000    48371.000000
# mean   2.134064e+06   2021.257179      6.692646        0.965144
# std    7.222183e+05      2.459768      3.039073        1.323983
# min    2.720160e+05   2015.000000      1.000000        0.000000
# 25%    1.713668e+06   2020.000000      5.000000        0.000000
# 50%    2.346406e+06   2022.000000      7.000000        1.000000
# 75%    2.691769e+06   2023.000000      9.000000        1.000000
# max    3.181158e+06   2025.000000     12.000000       60.000000
#
#        Victims_Injured  Suspects_Killed  Suspects_Injured  Suspects_Arrested  \
# count     48371.000000     48371.000000      48371.000000       48371.000000
# mean          4.167146         0.064109          0.047404           0.683571
# std           3.708707         0.252267          0.239318           1.142419
# min           0.000000         0.000000          0.000000           0.000000
# 25%           3.000000         0.000000          0.000000           0.000000
# 50%           4.000000         0.000000          0.000000           0.000000
# 75%           5.000000         0.000000          0.000000           1.000000
# max         439.000000         3.000000          5.000000          14.000000
#
#        Handguns_Sold  Long_Guns_Sold  Total_Guns_Sold           Lat  \
# count   48371.000000    48371.000000     48371.000000  48371.000000
# mean    29106.847305    18007.645201     47114.464845     38.287983
# std     23419.081251    12159.116460     34371.181760      4.380785
# min         0.000000        0.000000         0.000000     17.977800
# 25%     11740.000000     9880.000000     22656.000000     35.316900
# 50%     23085.000000    15348.000000     37597.000000     39.044800
# 75%     37859.000000    23422.000000     61953.000000     41.031800
# max    171600.000000   102546.000000    248724.000000     68.344500
#
#                Long    Population  Shootings_County  Shootings_State  \
# count  48371.000000  4.837100e+04      48371.000000     48371.000000
# mean     -89.950253  2.297070e+05         66.978934       455.253065
# std       10.917209  1.368722e+06         99.381771       318.305968
# min     -170.274300  0.000000e+00          1.000000         1.000000
# 25%      -94.379900  0.000000e+00          4.000000       198.000000
# 50%      -88.166600  1.554700e+04         20.000000       387.000000
# 75%      -82.985500  5.542700e+04         90.000000       669.000000
# max      -65.773300  3.129083e+07        483.000000      1303.000000
#
#        Total_Harmed_Victims
# count          48371.000000
# mean               5.132290
# std                4.039275
# min                0.000000
# 25%                4.000000
# 50%                4.000000
# 75%                5.000000
# max              499.000000

# %% [markdown]
# #### Gun Index

# %%
df_gunindex.head()
# Out:
#            State         Category Gun_Law_Strength Gun_Violence_Rate
# 0     California  National leader             90,5                 8
# 1  Massachusetts  National leader             86,5               3,7
# 2       Illinois  National leader               85              13,5
# 3       New York  National leader               85               4,7
# 4    Connecticut  National leader             81,5               6,2

# %%
df_gunindex.shape
# Out:
# (50, 4)

# %%
#Missing values check
df_gunindex.isnull().sum()
# Out:
# State                0
# Category             0
# Gun_Law_Strength     0
# Gun_Violence_Rate    0
# dtype: int64

# %%
#Duplicates check
dups_gindex = df_gunindex.duplicated()
dups_gindex.sum()
# Out:
# 0

# %%
df_gunindex.describe()
# Out:
#              State           Category Gun_Law_Strength Gun_Violence_Rate
# count           50                 50               50                50
# unique          50                  5               40                46
# top     California  National failures               14              21,5
# freq             1                 14                3                 2

# %%
df_gunindex.dtypes
# Out:
# State                object
# Category             object
# Gun_Law_Strength     object
# Gun_Violence_Rate    object
# dtype: object

# %%
#Converting data types in indexes
#Changing comma for period
cols = ['Gun_Law_Strength', 'Gun_Violence_Rate']

df_gunindex[cols] = df_gunindex[cols].apply(lambda x: x.astype(str).str.replace(',', '.', regex=False))

# %%
df_gunindex.head()
# Out:
#            State         Category Gun_Law_Strength Gun_Violence_Rate
# 0     California  National leader             90.5                 8
# 1  Massachusetts  National leader             86.5               3.7
# 2       Illinois  National leader               85              13.5
# 3       New York  National leader               85               4.7
# 4    Connecticut  National leader             81.5               6.2

# %%
#Changing data types
df_gunindex[cols] = df_gunindex[cols].astype(float)

# %%
df_gunindex.dtypes
# Out:
# State                 object
# Category              object
# Gun_Law_Strength     float64
# Gun_Violence_Rate    float64
# dtype: object

# %%
df_gunindex.describe()
# Out:
#        Gun_Law_Strength  Gun_Violence_Rate
# count          50.00000          50.000000
# mean           33.46000          15.212000
# std            28.89369           6.144573
# min             2.50000           3.700000
# 25%             9.50000          12.075000
# 50%            21.00000          14.500000
# 75%            58.75000          18.575000
# max            90.50000          29.400000

# %% [markdown]
# #### Population density by state

# %%
df_popdenstate.head()
# Out:
#         GEO.id  GEO.id2 GEO.display-label  \
# 0  0400000US01        1           Alabama
# 1  0400000US02        2            Alaska
# 2  0400000US04        4           Arizona
# 3  0400000US05        5          Arkansas
# 4  0400000US06        6        California
#
#    Density per square mile of land area
# 0                                  94.4
# 1                                   1.2
# 2                                  56.3
# 3                                  56.0
# 4                                 239.1

# %%
#Missing values check
df_popdenstate.isnull().sum()
# Out:
# GEO.id                                  0
# GEO.id2                                 0
# GEO.display-label                       0
# Density per square mile of land area    0
# dtype: int64

# %%
#Duplicates check
df_popdenstate = df_popdenstate.duplicated()
df_popdenstate.sum()
# Out:
# 0

# %%
df_popdenstate.dtypes
# Out:
# dtype('bool')

# %%
#Changing data types
cols_obj_denstate = ['GEO.id', 'GEO.id2', 'GEO.display-label']

df_popdenstate[cols_obj_denstate] = df_popdenstate[cols_obj_denstate].astype(str)

# %%
print(df_popdenstate.columns.tolist())
# Out:
# ['GEO.id', 'GEO.id2', 'GEO.display-label', 'Density per square mile of land area']

# %%
df_popdenstate.columns = df_popdenstate.columns.str.strip()

# %%
#Changing data types
cols_obj_denstate = ['GEO.id', 'GEO.id2', 'GEO.display-label']

df_popdenstate[cols_obj_denstate] = df_popdenstate[cols_obj_denstate].astype(str)

# %%
cols_float_denstate = ['Density per square mile of land area']

df_popdenstate[cols_float_denstate] = df_popdenstate[cols_float_denstate].astype(float)

# %%
df_popdenstate.dtypes
# Out:
# GEO.id                                   object
# GEO.id2                                  object
# GEO.display-label                        object
# Density per square mile of land area    float64
# dtype: object

# %%
df_popdenstate.describe()
# Out:
#        Density per square mile of land area
# count                             52.000000
# mean                             397.938462
# std                             1367.272141
# min                                1.200000
# 25%                               47.150000
# 50%                              103.050000
# 75%                              233.100000
# max                             9856.500000

# %% [markdown]
# #### Population density by county

# %%
df_popdencounty.head()
# Out:
#            County    State FIPS Code  Population  Area  Density
# 0  Autauga County  Alabama     01001       61464   594      103
# 1  Baldwin County  Alabama     01003      261608  1589      165
# 2  Barbour County  Alabama     01005       24358   884       28
# 3     Bibb County  Alabama     01007       22258   622       36
# 4   Blount County  Alabama     01009       60163   644       93

# %%
#Missing values check
df_popdencounty.isnull().sum()
# Out:
# County        0
# State         0
# FIPS Code     0
# Population    0
# Area          0
# Density       0
# dtype: int64

# %%
#Duplicates check
df_popdencounty = df_popdenstate.duplicated()
df_popdencounty.sum()
# Out:
# 0

# %%
#Checking data types
df_popdencounty.dtypes
# Out:
# dtype('bool')

# %%
print(df_popdencounty.columns.tolist())
# Out:
# ['County', 'State', 'FIPS Code', 'Population', 'Area', 'Density']

# %%
#Changing data types: object
cols_obj_dencounty = ['County', 'State', 'FIPS Code']

df_popdencounty[cols_obj_dencounty] = df_popdencounty[cols_obj_dencounty].astype(str)

# %%
#Changing data types: float
cols_obj_dencounty = ['Population', 'Area', 'Density']

df_popdencounty[cols_obj_dencounty] = df_popdencounty[cols_obj_dencounty].astype(float)

# %%
df_popdencounty.dtypes
# Out:
# County         object
# State          object
# FIPS Code      object
# Population    float64
# Area          float64
# Density       float64
# dtype: object

# %%
df_popdencounty.describe()
# Out:
#          Population           Area       Density
# count  3.048000e+03    3048.000000   3048.000000
# mean   1.022068e+05    1151.267060    283.357612
# std    3.333259e+05    6208.437897   1996.890935
# min    2.000000e+00       1.000000      0.000000
# 25%    9.844000e+03     434.000000     14.000000
# 50%    2.426000e+04     622.000000     41.000000
# 75%    6.576650e+04     934.250000    112.250000
# max    9.757179e+06  319852.000000  70915.000000

# %% [markdown]
# #### 3. Data wranging

# %% [markdown]
# #### Dropping unnecessary columns

# %% [markdown]
# #### Population density: State

# %%
df_popdenstate = df_popdenstate.drop(['GEO.id', 'GEO.id2'], axis=1)

# %%
df_popdenstate.head()
# Out:
#   GEO.display-label  Density per square mile of land area
# 0           Alabama                                  94.4
# 1            Alaska                                   1.2
# 2           Arizona                                  56.3
# 3          Arkansas                                  56.0
# 4        California                                 239.1

# %% [markdown]
# #### Population density: County

# %%
df_popdencounty = df_popdencounty.drop(['FIPS Code'], axis=1)

# %%
df_popdencounty.head()
# Out:
#            County    State  Population    Area  Density
# 0  Autauga County  Alabama     61464.0   594.0    103.0
# 1  Baldwin County  Alabama    261608.0  1589.0    165.0
# 2  Barbour County  Alabama     24358.0   884.0     28.0
# 3     Bibb County  Alabama     22258.0   622.0     36.0
# 4   Blount County  Alabama     60163.0   644.0     93.0

# %% [markdown]
# #### Changing column names and county names

# %%
#Changing column names in df_popdenstate
df_popdenstate.rename(columns={'GEO.display-label': 'State',
                               'Density per square mile of land area': 'Pop_Density_sqmi'}, inplace=True)

# %%
df_popdenstate.head()
# Out:
#         State  Pop_Density_sqmi
# 0     Alabama              94.4
# 1      Alaska               1.2
# 2     Arizona              56.3
# 3    Arkansas              56.0
# 4  California             239.1

# %%
#Changing column names in df_popdencounty
df_popdencounty.rename(columns={'Density': 'Cty_Pop_Density_sqmi'}, inplace=True)

# %%
#Dropping 'County' from county names to standardize with the master df
df_popdencounty['County'] = df_popdencounty['County'].str.replace(' County', '', regex=False)

# %%
df_popdencounty.head()
# Out:
#     County    State  Population    Area  Cty_Pop_Density_sqmi
# 0  Autauga  Alabama     61464.0   594.0                 103.0
# 1  Baldwin  Alabama    261608.0  1589.0                 165.0
# 2  Barbour  Alabama     24358.0   884.0                  28.0
# 3     Bibb  Alabama     22258.0   622.0                  36.0
# 4   Blount  Alabama     60163.0   644.0                  93.0

# %% [markdown]
# #### Merging datasets

# %%
df_merged = pd.merge(df, df_gunindex, on='State', how='left')
df_merged = pd.merge(df_merged, df_popdenstate, on='State', how='left')
df_merged = pd.merge(df_merged, df_popdencounty, on='County', how='left')

# %%
df_merged.head()
# Out:
#    Incident_ID        Date  Year  Month    State_x     City  Victims_Killed  \
# 0      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 1      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 2      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 3      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 4      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
#
#    Victims_Injured  Suspects_Killed  Suspects_Injured  Suspects_Arrested  \
# 0                5                0                 0                  0
# 1                5                0                 0                  0
# 2                5                0                 0                  0
# 3                5                0                 0                  0
# 4                5                0                 0                  0
#
#    Year_Month_State  Handguns_Sold  Long_Guns_Sold  Total_Guns_Sold State_ID  \
# 0  2025-4-Tennessee            0.0             0.0              0.0       TN
# 1  2025-4-Tennessee            0.0             0.0              0.0       TN
# 2  2025-4-Tennessee            0.0             0.0              0.0       TN
# 3  2025-4-Tennessee            0.0             0.0              0.0       TN
# 4  2025-4-Tennessee            0.0             0.0              0.0       TN
#
#      State_y  County      Lat     Long  Population_x  Shootings_County  \
# 0  Tennessee  Shelby  35.1087 -89.9663           0.0                 3
# 1  Tennessee  Shelby  35.1087 -89.9663           0.0                 3
# 2  Tennessee  Shelby  35.1087 -89.9663           0.0                 3
# 3  Tennessee  Shelby  35.1087 -89.9663           0.0                 3
# 4  Tennessee  Shelby  35.1087 -89.9663           0.0                 3
#
#    Shootings_State  Total_Harmed_Victims Any_Suspect_Arrested Category  \
# 0               30                     6                   No      NaN
# 1               30                     6                   No      NaN
# 2               30                     6                   No      NaN
# 3               30                     6                   No      NaN
# 4               30                     6                   No      NaN
#
#   Gun_Law_Strength Gun_Violence_Rate  Pop_Density_sqmi   State_y  \
# 0              NaN               NaN             153.9   Alabama
# 1              NaN               NaN             153.9  Illinois
# 2              NaN               NaN             153.9   Indiana
# 3              NaN               NaN             153.9      Iowa
# 4              NaN               NaN             153.9  Kentucky
#
#    Population_y   Area  Cty_Pop_Density_sqmi
# 0      235969.0  784.0                 301.0
# 1       20542.0  758.0                  27.0
# 2       45654.0  411.0                 111.0
# 3       11821.0  591.0                  20.0
# 4       50124.0  384.0                 131.0

# %%
#Missing value check
df_merged.isnull().sum()
# Out:
# Incident_ID                  0
# Date                         0
# Year                         0
# Month                        0
# State_x                      0
# City                         0
# Victims_Killed               0
# Victims_Injured              0
# Suspects_Killed              0
# Suspects_Injured             0
# Suspects_Arrested            0
# Year_Month_State             0
# Handguns_Sold                0
# Long_Guns_Sold               0
# Total_Guns_Sold              0
# State_ID                     0
# State_y                      0
# County                       0
# Lat                          0
# Long                         0
# Population_x                 0
# Shootings_County             0
# Shootings_State              0
# Total_Harmed_Victims         0
# Any_Suspect_Arrested         0
# Category                166016
# Gun_Law_Strength        166016
# Gun_Violence_Rate       166016
# Pop_Density_sqmi         13869
# State_y                   1579
# Population_y              1579
# Area                      1579
# Cty_Pop_Density_sqmi      1579
# dtype: int64

# %%
df_merged['Population_x'].value_counts()
# Out:
# Population_x
# 0.0         75520
# 34688.0      9000
# 770383.0     7500
# 35626.0      6300
# 34804.0      5400
#             ...
# 233031.0        1
# 29003.0         1
# 282963.0        1
# 81824.0         1
# 93439.0         1
# Name: count, Length: 5657, dtype: int64

# %%
df_merged[df_merged.isnull().any(axis=1)]
# Out:
#         Incident_ID        Date  Year  Month    State_x     City  \
# 0           3181158  2025-04-09  2025      4  Tennessee  Memphis
# 1           3181158  2025-04-09  2025      4  Tennessee  Memphis
# 2           3181158  2025-04-09  2025      4  Tennessee  Memphis
# 3           3181158  2025-04-09  2025      4  Tennessee  Memphis
# 4           3181158  2025-04-09  2025      4  Tennessee  Memphis
# ...             ...         ...   ...    ...        ...      ...
# 892627       272016  2015-01-01  2015      1  Tennessee  Memphis
# 892628       272016  2015-01-01  2015      1  Tennessee  Memphis
# 892629       272016  2015-01-01  2015      1  Tennessee  Memphis
# 892630       272016  2015-01-01  2015      1  Tennessee  Memphis
# 892631       272016  2015-01-01  2015      1  Tennessee  Memphis
#
#         Victims_Killed  Victims_Injured  Suspects_Killed  Suspects_Injured  \
# 0                    1                5                0                 0
# 1                    1                5                0                 0
# 2                    1                5                0                 0
# 3                    1                5                0                 0
# 4                    1                5                0                 0
# ...                ...              ...              ...               ...
# 892627               0                5                0                 0
# 892628               0                5                0                 0
# 892629               0                5                0                 0
# 892630               0                5                0                 0
# 892631               0                5                0                 0
#
#         Suspects_Arrested  Year_Month_State  Handguns_Sold  Long_Guns_Sold  \
# 0                       0  2025-4-Tennessee            0.0             0.0
# 1                       0  2025-4-Tennessee            0.0             0.0
# 2                       0  2025-4-Tennessee            0.0             0.0
# 3                       0  2025-4-Tennessee            0.0             0.0
# 4                       0  2025-4-Tennessee            0.0             0.0
# ...                   ...               ...            ...             ...
# 892627                  2  2015-1-Tennessee        25484.0         17575.0
# 892628                  2  2015-1-Tennessee        25484.0         17575.0
# 892629                  2  2015-1-Tennessee        25484.0         17575.0
# 892630                  2  2015-1-Tennessee        25484.0         17575.0
# 892631                  2  2015-1-Tennessee        25484.0         17575.0
#
#         Total_Guns_Sold State_ID    State_y    County      Lat     Long  \
# 0                   0.0       TN  Tennessee    Shelby  35.1087 -89.9663
# 1                   0.0       TN  Tennessee    Shelby  35.1087 -89.9663
# 2                   0.0       TN  Tennessee    Shelby  35.1087 -89.9663
# 3                   0.0       TN  Tennessee    Shelby  35.1087 -89.9663
# 4                   0.0       TN  Tennessee    Shelby  35.1087 -89.9663
# ...                 ...      ...        ...       ...      ...      ...
# 892627          43058.0       IN    Indiana     Clark  38.4891 -85.7679
# 892628          43058.0       IN    Indiana     Clark  38.4891 -85.7679
# 892629          43058.0       NE   Nebraska  Saunders  41.0946 -96.4332
# 892630          43058.0       AL    Alabama   Pickens  33.1369 -88.3008
# 892631          43058.0       AL    Alabama   Pickens  33.1369 -88.3008
#
#         Population_x  Shootings_County  Shootings_State  Total_Harmed_Victims  \
# 0                0.0                 3               30                     6
# 1                0.0                 3               30                     6
# 2                0.0                 3               30                     6
# 3                0.0                 3               30                     6
# 4                0.0                 3               30                     6
# ...              ...               ...              ...                   ...
# 892627           0.0                 5              386                     5
# 892628           0.0                 5              386                     5
# 892629           0.0                 3              386                     5
# 892630           0.0                 3              386                     5
# 892631           0.0                 3              386                     5
#
#        Any_Suspect_Arrested Category Gun_Law_Strength Gun_Violence_Rate  \
# 0                        No      NaN              NaN               NaN
# 1                        No      NaN              NaN               NaN
# 2                        No      NaN              NaN               NaN
# 3                        No      NaN              NaN               NaN
# 4                        No      NaN              NaN               NaN
# ...                     ...      ...              ...               ...
# 892627                  Yes      NaN              NaN               NaN
# 892628                  Yes      NaN              NaN               NaN
# 892629                  Yes      NaN              NaN               NaN
# 892630                  Yes      NaN              NaN               NaN
# 892631                  Yes      NaN              NaN               NaN
#
#         Pop_Density_sqmi     State_y  Population_y    Area  \
# 0                  153.9     Alabama      235969.0   784.0
# 1                  153.9    Illinois       20542.0   758.0
# 2                  153.9     Indiana       45654.0   411.0
# 3                  153.9        Iowa       11821.0   591.0
# 4                  153.9    Kentucky       50124.0   384.0
# ...                  ...         ...           ...     ...
# 892627             153.9  Washington      527269.0    11.0
# 892628             153.9   Wisconsin       34801.0  1209.0
# 892629             153.9    Nebraska       23406.0   754.0
# 892630             153.9     Alabama       18508.0   881.0
# 892631             153.9     Georgia       36580.0   232.0
#
#         Cty_Pop_Density_sqmi
# 0                      301.0
# 1                       27.0
# 2                      111.0
# 3                       20.0
# 4                      131.0
# ...                      ...
# 892627               47934.0
# 892628                  29.0
# 892629                  31.0
# 892630                  21.0
# 892631                 158.0
#
# [167294 rows x 33 columns]

# %%
#Duplicates check
dups_merged = df_merged.duplicated()

# %%
df_merged[df_merged.duplicated()]
# Out:
#         Incident_ID        Date  Year  Month    State_x      City  \
# 553985      1582816  2019-12-29  2019     12   Illinois  Danville
# 553986      1582816  2019-12-29  2019     12   Illinois  Danville
# 553987      1582816  2019-12-29  2019     12   Illinois  Danville
# 553988      1582816  2019-12-29  2019     12   Illinois  Danville
# 553989      1582816  2019-12-29  2019     12   Illinois  Danville
# ...             ...         ...   ...    ...        ...       ...
# 892605       272016  2015-01-01  2015      1  Tennessee   Memphis
# 892606       272016  2015-01-01  2015      1  Tennessee   Memphis
# 892607       272016  2015-01-01  2015      1  Tennessee   Memphis
# 892608       272016  2015-01-01  2015      1  Tennessee   Memphis
# 892609       272016  2015-01-01  2015      1  Tennessee   Memphis
#
#         Victims_Killed  Victims_Injured  Suspects_Killed  Suspects_Injured  \
# 553985               0                5                0                 0
# 553986               0                5                0                 0
# 553987               0                5                0                 0
# 553988               0                5                0                 0
# 553989               0                5                0                 0
# ...                ...              ...              ...               ...
# 892605               0                5                0                 0
# 892606               0                5                0                 0
# 892607               0                5                0                 0
# 892608               0                5                0                 0
# 892609               0                5                0                 0
#
#         Suspects_Arrested  Year_Month_State  Handguns_Sold  Long_Guns_Sold  \
# 553985                  0  2019-12-Illinois        28489.0         15802.0
# 553986                  0  2019-12-Illinois        28489.0         15802.0
# 553987                  0  2019-12-Illinois        28489.0         15802.0
# 553988                  0  2019-12-Illinois        28489.0         15802.0
# 553989                  0  2019-12-Illinois        28489.0         15802.0
# ...                   ...               ...            ...             ...
# 892605                  2  2015-1-Tennessee        25484.0         17575.0
# 892606                  2  2015-1-Tennessee        25484.0         17575.0
# 892607                  2  2015-1-Tennessee        25484.0         17575.0
# 892608                  2  2015-1-Tennessee        25484.0         17575.0
# 892609                  2  2015-1-Tennessee        25484.0         17575.0
#
#         Total_Guns_Sold State_ID    State_y  County      Lat     Long  \
# 553985          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# 553986          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# 553987          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# 553988          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# 553989          44290.0       OH       Ohio    Knox  40.4473 -82.2612
# ...                 ...      ...        ...     ...      ...      ...
# 892605          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
# 892606          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
# 892607          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
# 892608          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
# 892609          43058.0       TN  Tennessee  Shelby  35.1087 -89.9663
#
#         Population_x  Shootings_County  Shootings_State  Total_Harmed_Victims  \
# 553985       49669.0                 9              333                     5
# 553986       49669.0                 9              333                     5
# 553987       49669.0                 9              333                     5
# 553988       49669.0                 9              333                     5
# 553989       49669.0                 9              333                     5
# ...              ...               ...              ...                   ...
# 892605      937598.0                27              386                     5
# 892606      937598.0                27              386                     5
# 892607      937598.0                27              386                     5
# 892608      937598.0                27              386                     5
# 892609      937598.0                27              386                     5
#
#        Any_Suspect_Arrested         Category Gun_Law_Strength  \
# 553985                   No  National leader               85
# 553986                   No  National leader               85
# 553987                   No  National leader               85
# 553988                   No  National leader               85
# 553989                   No  National leader               85
# ...                     ...              ...              ...
# 892605                  Yes              NaN              NaN
# 892606                  Yes              NaN              NaN
# 892607                  Yes              NaN              NaN
# 892608                  Yes              NaN              NaN
# 892609                  Yes              NaN              NaN
#
#        Gun_Violence_Rate  Pop_Density_sqmi    State_y  Population_y    Area  \
# 553985              13,5             231.1   Illinois       48716.0   716.0
# 553986              13,5             231.1    Indiana       35872.0   516.0
# 553987              13,5             231.1   Kentucky       29657.0   388.0
# 553988              13,5             231.1      Maine       40981.0  1142.0
# 553989              13,5             231.1   Missouri        3740.0   506.0
# ...                  ...               ...        ...           ...     ...
# 892605               NaN             153.9   Kentucky       50124.0   384.0
# 892606               NaN             153.9   Missouri        5926.0   501.0
# 892607               NaN             153.9       Ohio       47952.0   409.0
# 892608               NaN             153.9  Tennessee      910530.0   755.0
# 892609               NaN             153.9      Texas       24192.0   794.0
#
#         Cty_Pop_Density_sqmi
# 553985                  68.0
# 553986                  70.0
# 553987                  76.0
# 553988                  36.0
# 553989                   7.0
# ...                      ...
# 892605                 131.0
# 892606                  12.0
# 892607                 117.0
# 892608                1206.0
# 892609                  30.0
#
# [290516 rows x 33 columns]

# %%
#Dropping duplicates
df_merged = df_merged.drop_duplicates()

# %%
df_merged[df_merged.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Incident_ID, Date, Year, Month, State_x, City, Victims_Killed, Victims_Injured, Suspects_Killed, Suspects_Injured, Suspects_Arrested, Year_Month_State, Handguns_Sold, Long_Guns_Sold, Total_Guns_Sold, State_ID, State_y, County, Lat, Long, Population_x, Shootings_County, Shootings_State, Total_Harmed_Victims, Any_Suspect_Arrested, Category, Gun_Law_Strength, Gun_Violence_Rate, Pop_Density_sqmi, State_y, Population_y, Area, Cty_Pop_Density_sqmi]
# Index: []

# %%
#Dropping unnecessary columns

# %%
df_merged.dtypes
# Out:
# Incident_ID               int64
# Date                     object
# Year                      int64
# Month                     int64
# State_x                  object
# City                     object
# Victims_Killed            int64
# Victims_Injured           int64
# Suspects_Killed           int64
# Suspects_Injured          int64
# Suspects_Arrested         int64
# Year_Month_State         object
# Handguns_Sold           float64
# Long_Guns_Sold          float64
# Total_Guns_Sold         float64
# State_ID                 object
# State_y                  object
# County                   object
# Lat                     float64
# Long                    float64
# Population_x            float64
# Shootings_County          int64
# Shootings_State           int64
# Total_Harmed_Victims      int64
# Any_Suspect_Arrested     object
# Category                 object
# Gun_Law_Strength         object
# Gun_Violence_Rate        object
# Pop_Density_sqmi        float64
# State_y                  object
# Population_y            float64
# Area                    float64
# Cty_Pop_Density_sqmi    float64
# dtype: object

# %%
df_merged = df_merged.drop(columns=['State_y'])

# %%
df_merged = df_merged.drop(['State_ID', 'Any_Suspect_Arrested', 'Population_y', 'Area'], axis=1)

# %%
df_merged.columns
# Out:
# Index(['Incident_ID', 'Date', 'Year', 'Month', 'State', 'City',
#        'Victims_Killed', 'Victims_Injured', 'Suspects_Killed',
#        'Suspects_Injured', 'Suspects_Arrested', 'Year_Month_State',
#        'Handguns_Sold', 'Long_Guns_Sold', 'Total_Guns_Sold', 'State_ID',
#        'State_y', 'County', 'Lat', 'Long', 'Population', 'Shootings_County',
#        'Shootings_State', 'Total_Harmed_Victims', 'Any_Suspect_Arrested',
#        'Category', 'Gun_Law_Strength', 'Gun_Violence_Rate',
#        'St_Pop_Density_sqmi', 'State_y', 'Population_y', 'Area',
#        'Cty_Pop_Density_sqmi'],
#       dtype='object')

# %%
#Changing column names in df_popdencounty
df_merged.rename(columns={'State_x': 'State',
                            'Population_x': 'Population', 
                            'Pop_Density_sqmi': 'St_Pop_Density_sqmi',
                            }, inplace=True)
# Out:
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_19392\1092337948.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merged.rename(columns={'State_x': 'State',

# %%
df_merged.head()
# Out:
#    Incident_ID        Date  Year  Month      State     City  Victims_Killed  \
# 0      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 1      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 2      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 3      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
# 4      3181158  2025-04-09  2025      4  Tennessee  Memphis               1
#
#    Victims_Injured  Suspects_Killed  Suspects_Injured  Suspects_Arrested  \
# 0                5                0                 0                  0
# 1                5                0                 0                  0
# 2                5                0                 0                  0
# 3                5                0                 0                  0
# 4                5                0                 0                  0
#
#    Year_Month_State  Handguns_Sold  Long_Guns_Sold  Total_Guns_Sold State_ID  \
# 0  2025-4-Tennessee            0.0             0.0              0.0       TN
# 1  2025-4-Tennessee            0.0             0.0              0.0       TN
# 2  2025-4-Tennessee            0.0             0.0              0.0       TN
# 3  2025-4-Tennessee            0.0             0.0              0.0       TN
# 4  2025-4-Tennessee            0.0             0.0              0.0       TN
#
#      State_y  County      Lat     Long  Population  Shootings_County  \
# 0  Tennessee  Shelby  35.1087 -89.9663         0.0                 3
# 1  Tennessee  Shelby  35.1087 -89.9663         0.0                 3
# 2  Tennessee  Shelby  35.1087 -89.9663         0.0                 3
# 3  Tennessee  Shelby  35.1087 -89.9663         0.0                 3
# 4  Tennessee  Shelby  35.1087 -89.9663         0.0                 3
#
#    Shootings_State  Total_Harmed_Victims Any_Suspect_Arrested Category  \
# 0               30                     6                   No      NaN
# 1               30                     6                   No      NaN
# 2               30                     6                   No      NaN
# 3               30                     6                   No      NaN
# 4               30                     6                   No      NaN
#
#   Gun_Law_Strength Gun_Violence_Rate  St_Pop_Density_sqmi   State_y  \
# 0              NaN               NaN                153.9   Alabama
# 1              NaN               NaN                153.9  Illinois
# 2              NaN               NaN                153.9   Indiana
# 3              NaN               NaN                153.9      Iowa
# 4              NaN               NaN                153.9  Kentucky
#
#    Population_y   Area  Cty_Pop_Density_sqmi
# 0      235969.0  784.0                 301.0
# 1       20542.0  758.0                  27.0
# 2       45654.0  411.0                 111.0
# 3       11821.0  591.0                  20.0
# 4       50124.0  384.0                 131.0

# %%
df_merged.columns
# Out:
# Index(['Incident_ID', 'Date', 'Year', 'Month', 'State', 'City',
#        'Victims_Killed', 'Victims_Injured', 'Suspects_Killed',
#        'Suspects_Injured', 'Suspects_Arrested', 'Year_Month_State',
#        'Handguns_Sold', 'Long_Guns_Sold', 'Total_Guns_Sold', 'State_ID',
#        'State_y', 'County', 'Lat', 'Long', 'Population', 'Shootings_County',
#        'Shootings_State', 'Total_Harmed_Victims', 'Any_Suspect_Arrested',
#        'Category', 'Gun_Law_Strength', 'Gun_Violence_Rate',
#        'St_Pop_Density_sqmi', 'State_y', 'Population_y', 'Area',
#        'Cty_Pop_Density_sqmi'],
#       dtype='object')

# %%
#Reorganizing table order
new_order = ['Incident_ID', 'Date', 'Year', 'Month', 'Year_Month_State', 'State', 'County', 'City', 'Lat',
       'Long', 'Population', 'St_Pop_Density_sqmi', 'Cty_Pop_Density_sqmi', 'Victims_Killed', 'Victims_Injured', 'Total_Harmed_Victims', 'Suspects_Killed',
       'Suspects_Injured', 'Suspects_Arrested', 'Shootings_State', 'Shootings_County',
       'Handguns_Sold', 'Long_Guns_Sold', 'Total_Guns_Sold', 'Gun_Law_Strength',
       'Gun_Violence_Rate', 'Category']  
df_merged = df_merged[new_order]

# %%
df_merged
# Out:
#         Incident_ID        Date  Year  Month  Year_Month_State      State  \
# 0           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 1           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 2           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 3           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 4           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# ...             ...         ...   ...    ...               ...        ...
# 892627       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 892628       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 892629       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 892630       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 892631       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
#
#           County     City      Lat     Long  Population  St_Pop_Density_sqmi  \
# 0         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 1         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 2         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 3         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 4         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# ...          ...      ...      ...      ...         ...                  ...
# 892627     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 892628     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 892629  Saunders  Memphis  41.0946 -96.4332         0.0                153.9
# 892630   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
# 892631   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
#
#         Cty_Pop_Density_sqmi  Victims_Killed  Victims_Injured  \
# 0                      301.0               1                5
# 1                       27.0               1                5
# 2                      111.0               1                5
# 3                       20.0               1                5
# 4                      131.0               1                5
# ...                      ...             ...              ...
# 892627               47934.0               0                5
# 892628                  29.0               0                5
# 892629                  31.0               0                5
# 892630                  21.0               0                5
# 892631                 158.0               0                5
#
#         Total_Harmed_Victims  Suspects_Killed  Suspects_Injured  \
# 0                          6                0                 0
# 1                          6                0                 0
# 2                          6                0                 0
# 3                          6                0                 0
# 4                          6                0                 0
# ...                      ...              ...               ...
# 892627                     5                0                 0
# 892628                     5                0                 0
# 892629                     5                0                 0
# 892630                     5                0                 0
# 892631                     5                0                 0
#
#         Suspects_Arrested  Shootings_State  Shootings_County  Handguns_Sold  \
# 0                       0               30                 3            0.0
# 1                       0               30                 3            0.0
# 2                       0               30                 3            0.0
# 3                       0               30                 3            0.0
# 4                       0               30                 3            0.0
# ...                   ...              ...               ...            ...
# 892627                  2              386                 5        25484.0
# 892628                  2              386                 5        25484.0
# 892629                  2              386                 3        25484.0
# 892630                  2              386                 3        25484.0
# 892631                  2              386                 3        25484.0
#
#         Long_Guns_Sold  Total_Guns_Sold Gun_Law_Strength Gun_Violence_Rate  \
# 0                  0.0              0.0              NaN               NaN
# 1                  0.0              0.0              NaN               NaN
# 2                  0.0              0.0              NaN               NaN
# 3                  0.0              0.0              NaN               NaN
# 4                  0.0              0.0              NaN               NaN
# ...                ...              ...              ...               ...
# 892627         17575.0          43058.0              NaN               NaN
# 892628         17575.0          43058.0              NaN               NaN
# 892629         17575.0          43058.0              NaN               NaN
# 892630         17575.0          43058.0              NaN               NaN
# 892631         17575.0          43058.0              NaN               NaN
#
#        Category
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 892627      NaN
# 892628      NaN
# 892629      NaN
# 892630      NaN
# 892631      NaN
#
# [602116 rows x 27 columns]

# %%
df_merged[df_merged.isnull().any(axis=1)]
# Out:
#         Incident_ID        Date  Year  Month  Year_Month_State      State  \
# 0           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 1           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 2           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 3           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 4           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# ...             ...         ...   ...    ...               ...        ...
# 892627       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 892628       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 892629       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 892630       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 892631       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
#
#           County     City      Lat     Long  Population  St_Pop_Density_sqmi  \
# 0         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 1         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 2         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 3         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 4         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# ...          ...      ...      ...      ...         ...                  ...
# 892627     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 892628     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 892629  Saunders  Memphis  41.0946 -96.4332         0.0                153.9
# 892630   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
# 892631   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
#
#         Cty_Pop_Density_sqmi  Victims_Killed  Victims_Injured  \
# 0                      301.0               1                5
# 1                       27.0               1                5
# 2                      111.0               1                5
# 3                       20.0               1                5
# 4                      131.0               1                5
# ...                      ...             ...              ...
# 892627               47934.0               0                5
# 892628                  29.0               0                5
# 892629                  31.0               0                5
# 892630                  21.0               0                5
# 892631                 158.0               0                5
#
#         Total_Harmed_Victims  Suspects_Killed  Suspects_Injured  \
# 0                          6                0                 0
# 1                          6                0                 0
# 2                          6                0                 0
# 3                          6                0                 0
# 4                          6                0                 0
# ...                      ...              ...               ...
# 892627                     5                0                 0
# 892628                     5                0                 0
# 892629                     5                0                 0
# 892630                     5                0                 0
# 892631                     5                0                 0
#
#         Suspects_Arrested  Shootings_State  Shootings_County  Handguns_Sold  \
# 0                       0               30                 3            0.0
# 1                       0               30                 3            0.0
# 2                       0               30                 3            0.0
# 3                       0               30                 3            0.0
# 4                       0               30                 3            0.0
# ...                   ...              ...               ...            ...
# 892627                  2              386                 5        25484.0
# 892628                  2              386                 5        25484.0
# 892629                  2              386                 3        25484.0
# 892630                  2              386                 3        25484.0
# 892631                  2              386                 3        25484.0
#
#         Long_Guns_Sold  Total_Guns_Sold Gun_Law_Strength Gun_Violence_Rate  \
# 0                  0.0              0.0              NaN               NaN
# 1                  0.0              0.0              NaN               NaN
# 2                  0.0              0.0              NaN               NaN
# 3                  0.0              0.0              NaN               NaN
# 4                  0.0              0.0              NaN               NaN
# ...                ...              ...              ...               ...
# 892627         17575.0          43058.0              NaN               NaN
# 892628         17575.0          43058.0              NaN               NaN
# 892629         17575.0          43058.0              NaN               NaN
# 892630         17575.0          43058.0              NaN               NaN
# 892631         17575.0          43058.0              NaN               NaN
#
#        Category
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 892627      NaN
# 892628      NaN
# 892629      NaN
# 892630      NaN
# 892631      NaN
#
# [135490 rows x 27 columns]

# %%
#Correcting bad merge
df_merged = df_merged.drop(['Gun_Law_Strength', 'Gun_Violence_Rate', 'Category'], axis=1)

# %%
df_merged = pd.merge(df_merged, df_gunindex, on='State', how='left')

# %%
df_merged
# Out:
#         Incident_ID        Date  Year  Month  Year_Month_State      State  \
# 0           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 1           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 2           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 3           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 4           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# ...             ...         ...   ...    ...               ...        ...
# 602111       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602112       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602113       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602114       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602115       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
#
#           County     City      Lat     Long  Population  St_Pop_Density_sqmi  \
# 0         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 1         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 2         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 3         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 4         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# ...          ...      ...      ...      ...         ...                  ...
# 602111     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602112     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602113  Saunders  Memphis  41.0946 -96.4332         0.0                153.9
# 602114   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
# 602115   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
#
#         Cty_Pop_Density_sqmi  Victims_Killed  Victims_Injured  \
# 0                      301.0               1                5
# 1                       27.0               1                5
# 2                      111.0               1                5
# 3                       20.0               1                5
# 4                      131.0               1                5
# ...                      ...             ...              ...
# 602111               47934.0               0                5
# 602112                  29.0               0                5
# 602113                  31.0               0                5
# 602114                  21.0               0                5
# 602115                 158.0               0                5
#
#         Total_Harmed_Victims  Suspects_Killed  Suspects_Injured  \
# 0                          6                0                 0
# 1                          6                0                 0
# 2                          6                0                 0
# 3                          6                0                 0
# 4                          6                0                 0
# ...                      ...              ...               ...
# 602111                     5                0                 0
# 602112                     5                0                 0
# 602113                     5                0                 0
# 602114                     5                0                 0
# 602115                     5                0                 0
#
#         Suspects_Arrested  Shootings_State  Shootings_County  Handguns_Sold  \
# 0                       0               30                 3            0.0
# 1                       0               30                 3            0.0
# 2                       0               30                 3            0.0
# 3                       0               30                 3            0.0
# 4                       0               30                 3            0.0
# ...                   ...              ...               ...            ...
# 602111                  2              386                 5        25484.0
# 602112                  2              386                 5        25484.0
# 602113                  2              386                 3        25484.0
# 602114                  2              386                 3        25484.0
# 602115                  2              386                 3        25484.0
#
#         Long_Guns_Sold  Total_Guns_Sold Category Gun_Law_Strength  \
# 0                  0.0              0.0      NaN              NaN
# 1                  0.0              0.0      NaN              NaN
# 2                  0.0              0.0      NaN              NaN
# 3                  0.0              0.0      NaN              NaN
# 4                  0.0              0.0      NaN              NaN
# ...                ...              ...      ...              ...
# 602111         17575.0          43058.0      NaN              NaN
# 602112         17575.0          43058.0      NaN              NaN
# 602113         17575.0          43058.0      NaN              NaN
# 602114         17575.0          43058.0      NaN              NaN
# 602115         17575.0          43058.0      NaN              NaN
#
#        Gun_Violence_Rate
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 602111               NaN
# 602112               NaN
# 602113               NaN
# 602114               NaN
# 602115               NaN
#
# [602116 rows x 27 columns]

# %%
df_merged[df_merged[['Category', 'Gun_Law_Strength', 'Gun_Violence_Rate']].isnull().any(axis=1)]
# Out:
#         Incident_ID        Date  Year  Month  Year_Month_State      State  \
# 0           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 1           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 2           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 3           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 4           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# ...             ...         ...   ...    ...               ...        ...
# 602111       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602112       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602113       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602114       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602115       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
#
#           County     City      Lat     Long  Population  St_Pop_Density_sqmi  \
# 0         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 1         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 2         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 3         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 4         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# ...          ...      ...      ...      ...         ...                  ...
# 602111     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602112     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602113  Saunders  Memphis  41.0946 -96.4332         0.0                153.9
# 602114   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
# 602115   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
#
#         Cty_Pop_Density_sqmi  Victims_Killed  Victims_Injured  \
# 0                      301.0               1                5
# 1                       27.0               1                5
# 2                      111.0               1                5
# 3                       20.0               1                5
# 4                      131.0               1                5
# ...                      ...             ...              ...
# 602111               47934.0               0                5
# 602112                  29.0               0                5
# 602113                  31.0               0                5
# 602114                  21.0               0                5
# 602115                 158.0               0                5
#
#         Total_Harmed_Victims  Suspects_Killed  Suspects_Injured  \
# 0                          6                0                 0
# 1                          6                0                 0
# 2                          6                0                 0
# 3                          6                0                 0
# 4                          6                0                 0
# ...                      ...              ...               ...
# 602111                     5                0                 0
# 602112                     5                0                 0
# 602113                     5                0                 0
# 602114                     5                0                 0
# 602115                     5                0                 0
#
#         Suspects_Arrested  Shootings_State  Shootings_County  Handguns_Sold  \
# 0                       0               30                 3            0.0
# 1                       0               30                 3            0.0
# 2                       0               30                 3            0.0
# 3                       0               30                 3            0.0
# 4                       0               30                 3            0.0
# ...                   ...              ...               ...            ...
# 602111                  2              386                 5        25484.0
# 602112                  2              386                 5        25484.0
# 602113                  2              386                 3        25484.0
# 602114                  2              386                 3        25484.0
# 602115                  2              386                 3        25484.0
#
#         Long_Guns_Sold  Total_Guns_Sold Category Gun_Law_Strength  \
# 0                  0.0              0.0      NaN              NaN
# 1                  0.0              0.0      NaN              NaN
# 2                  0.0              0.0      NaN              NaN
# 3                  0.0              0.0      NaN              NaN
# 4                  0.0              0.0      NaN              NaN
# ...                ...              ...      ...              ...
# 602111         17575.0          43058.0      NaN              NaN
# 602112         17575.0          43058.0      NaN              NaN
# 602113         17575.0          43058.0      NaN              NaN
# 602114         17575.0          43058.0      NaN              NaN
# 602115         17575.0          43058.0      NaN              NaN
#
#        Gun_Violence_Rate
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 602111               NaN
# 602112               NaN
# 602113               NaN
# 602114               NaN
# 602115               NaN
#
# [134292 rows x 27 columns]

# %%
df_merged['State'] = df_merged['State'].str.strip()
df_gunindex['State'] = df_gunindex['State'].str.strip()

# %%
print(df_merged['State'].dtype, df_gunindex['State'].dtype)
# Out:
# object object

# %%
df_merged.columns = df_merged.columns.str.strip()
df_gunindex.columns = df_gunindex.columns.str.strip()

# %%
print(set(df_merged['State']).difference(set(df_gunindex['State'])))
# Out:
# {'Tennessee', 'Wyoming', 'District Of Columbia', 'Mississippi'}

# %%
#Fixing typos
df_gunindex['State'] = df_gunindex['State'].replace({
    'Wyopming': 'Wyoming',
    'Mississipi': 'Mississippi',
    'Tennesee': 'Tennessee'
})

# %%
#Adding new entry
new_row = {
    'State': 'District of Columbia',
    'Category': 'none',
    'Gun_Law_Strength': 0,
    'Gun_Violence_Rate': 0
}

df_gunindex = pd.concat([df_gunindex, pd.DataFrame([new_row])], ignore_index=True)

# %%
#Retrying merge
df_merged = pd.merge(df_merged, df_gunindex, on='State', how='left')

# %%
df_merged[df_merged.isnull().any(axis=1)]
# Out:
#         Incident_ID        Date  Year  Month  Year_Month_State      State  \
# 0           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 1           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 2           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 3           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 4           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# ...             ...         ...   ...    ...               ...        ...
# 602111       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602112       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602113       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602114       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602115       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
#
#           County     City      Lat     Long  Population  St_Pop_Density_sqmi  \
# 0         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 1         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 2         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 3         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 4         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# ...          ...      ...      ...      ...         ...                  ...
# 602111     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602112     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602113  Saunders  Memphis  41.0946 -96.4332         0.0                153.9
# 602114   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
# 602115   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
#
#         Cty_Pop_Density_sqmi  Victims_Killed  Victims_Injured  \
# 0                      301.0               1                5
# 1                       27.0               1                5
# 2                      111.0               1                5
# 3                       20.0               1                5
# 4                      131.0               1                5
# ...                      ...             ...              ...
# 602111               47934.0               0                5
# 602112                  29.0               0                5
# 602113                  31.0               0                5
# 602114                  21.0               0                5
# 602115                 158.0               0                5
#
#         Total_Harmed_Victims  Suspects_Killed  Suspects_Injured  \
# 0                          6                0                 0
# 1                          6                0                 0
# 2                          6                0                 0
# 3                          6                0                 0
# 4                          6                0                 0
# ...                      ...              ...               ...
# 602111                     5                0                 0
# 602112                     5                0                 0
# 602113                     5                0                 0
# 602114                     5                0                 0
# 602115                     5                0                 0
#
#         Suspects_Arrested  Shootings_State  Shootings_County  Handguns_Sold  \
# 0                       0               30                 3            0.0
# 1                       0               30                 3            0.0
# 2                       0               30                 3            0.0
# 3                       0               30                 3            0.0
# 4                       0               30                 3            0.0
# ...                   ...              ...               ...            ...
# 602111                  2              386                 5        25484.0
# 602112                  2              386                 5        25484.0
# 602113                  2              386                 3        25484.0
# 602114                  2              386                 3        25484.0
# 602115                  2              386                 3        25484.0
#
#         Long_Guns_Sold  Total_Guns_Sold Category_x Gun_Law_Strength_x  \
# 0                  0.0              0.0        NaN                NaN
# 1                  0.0              0.0        NaN                NaN
# 2                  0.0              0.0        NaN                NaN
# 3                  0.0              0.0        NaN                NaN
# 4                  0.0              0.0        NaN                NaN
# ...                ...              ...        ...                ...
# 602111         17575.0          43058.0        NaN                NaN
# 602112         17575.0          43058.0        NaN                NaN
# 602113         17575.0          43058.0        NaN                NaN
# 602114         17575.0          43058.0        NaN                NaN
# 602115         17575.0          43058.0        NaN                NaN
#
#        Gun_Violence_Rate_x    Category_y Gun_Law_Strength_y  \
# 0                      NaN  Weak systems                 14
# 1                      NaN  Weak systems                 14
# 2                      NaN  Weak systems                 14
# 3                      NaN  Weak systems                 14
# 4                      NaN  Weak systems                 14
# ...                    ...           ...                ...
# 602111                 NaN  Weak systems                 14
# 602112                 NaN  Weak systems                 14
# 602113                 NaN  Weak systems                 14
# 602114                 NaN  Weak systems                 14
# 602115                 NaN  Weak systems                 14
#
#        Gun_Violence_Rate_y
# 0                       22
# 1                       22
# 2                       22
# 3                       22
# 4                       22
# ...                    ...
# 602111                  22
# 602112                  22
# 602113                  22
# 602114                  22
# 602115                  22
#
# [135490 rows x 30 columns]

# %%
#Dropping bad columns
df_merged = df_merged.drop(['Category_x', 'Gun_Law_Strength_x', 'Gun_Violence_Rate_x'], axis=1)

# %%
#Changing column names 
df_merged.rename(columns={'Category_y': 'Category',
                            'Gun_Law_Strength_y': 'Gun_Law_Strength', 
                            'Gun_Violence_Rate_y': 'Gun_Violence_Rate'
                            }, inplace=True)

# %%
#Reorganizing table order
new_order = ['Incident_ID', 'Date', 'Year', 'Month', 'Year_Month_State', 'State', 'County', 'City', 'Lat',
       'Long', 'Population', 'St_Pop_Density_sqmi', 'Cty_Pop_Density_sqmi', 'Victims_Killed', 'Victims_Injured', 'Total_Harmed_Victims', 'Suspects_Killed',
       'Suspects_Injured', 'Suspects_Arrested', 'Shootings_State', 'Shootings_County',
       'Handguns_Sold', 'Long_Guns_Sold', 'Total_Guns_Sold', 'Gun_Law_Strength',
       'Gun_Violence_Rate', 'Category']  

df_merged = df_merged[new_order]

# %%
df_merged
# Out:
#         Incident_ID        Date  Year  Month  Year_Month_State      State  \
# 0           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 1           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 2           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 3           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 4           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# ...             ...         ...   ...    ...               ...        ...
# 602111       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602112       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602113       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602114       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602115       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
#
#           County     City      Lat     Long  Population  St_Pop_Density_sqmi  \
# 0         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 1         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 2         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 3         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 4         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# ...          ...      ...      ...      ...         ...                  ...
# 602111     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602112     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602113  Saunders  Memphis  41.0946 -96.4332         0.0                153.9
# 602114   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
# 602115   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
#
#         Cty_Pop_Density_sqmi  Victims_Killed  Victims_Injured  \
# 0                      301.0               1                5
# 1                       27.0               1                5
# 2                      111.0               1                5
# 3                       20.0               1                5
# 4                      131.0               1                5
# ...                      ...             ...              ...
# 602111               47934.0               0                5
# 602112                  29.0               0                5
# 602113                  31.0               0                5
# 602114                  21.0               0                5
# 602115                 158.0               0                5
#
#         Total_Harmed_Victims  Suspects_Killed  Suspects_Injured  \
# 0                          6                0                 0
# 1                          6                0                 0
# 2                          6                0                 0
# 3                          6                0                 0
# 4                          6                0                 0
# ...                      ...              ...               ...
# 602111                     5                0                 0
# 602112                     5                0                 0
# 602113                     5                0                 0
# 602114                     5                0                 0
# 602115                     5                0                 0
#
#         Suspects_Arrested  Shootings_State  Shootings_County  Handguns_Sold  \
# 0                       0               30                 3            0.0
# 1                       0               30                 3            0.0
# 2                       0               30                 3            0.0
# 3                       0               30                 3            0.0
# 4                       0               30                 3            0.0
# ...                   ...              ...               ...            ...
# 602111                  2              386                 5        25484.0
# 602112                  2              386                 5        25484.0
# 602113                  2              386                 3        25484.0
# 602114                  2              386                 3        25484.0
# 602115                  2              386                 3        25484.0
#
#         Long_Guns_Sold  Total_Guns_Sold Gun_Law_Strength Gun_Violence_Rate  \
# 0                  0.0              0.0               14                22
# 1                  0.0              0.0               14                22
# 2                  0.0              0.0               14                22
# 3                  0.0              0.0               14                22
# 4                  0.0              0.0               14                22
# ...                ...              ...              ...               ...
# 602111         17575.0          43058.0               14                22
# 602112         17575.0          43058.0               14                22
# 602113         17575.0          43058.0               14                22
# 602114         17575.0          43058.0               14                22
# 602115         17575.0          43058.0               14                22
#
#             Category
# 0       Weak systems
# 1       Weak systems
# 2       Weak systems
# 3       Weak systems
# 4       Weak systems
# ...              ...
# 602111  Weak systems
# 602112  Weak systems
# 602113  Weak systems
# 602114  Weak systems
# 602115  Weak systems
#
# [602116 rows x 27 columns]

# %%
dups_final = df_merged.duplicated()
dups_final.sum()
# Out:
# 24549

# %%
df_merged_final = df_merged.drop_duplicates()

# %%
dups_final2 = df_merged_final.duplicated()
dups_final2.sum()
# Out:
# 0

# %%
df_merged_final
# Out:
#         Incident_ID        Date  Year  Month  Year_Month_State      State  \
# 0           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 1           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 2           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 3           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 4           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# ...             ...         ...   ...    ...               ...        ...
# 602111       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602112       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602113       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602114       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602115       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
#
#           County     City      Lat     Long  Population  St_Pop_Density_sqmi  \
# 0         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 1         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 2         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 3         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 4         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# ...          ...      ...      ...      ...         ...                  ...
# 602111     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602112     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602113  Saunders  Memphis  41.0946 -96.4332         0.0                153.9
# 602114   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
# 602115   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
#
#         Cty_Pop_Density_sqmi  Victims_Killed  Victims_Injured  \
# 0                      301.0               1                5
# 1                       27.0               1                5
# 2                      111.0               1                5
# 3                       20.0               1                5
# 4                      131.0               1                5
# ...                      ...             ...              ...
# 602111               47934.0               0                5
# 602112                  29.0               0                5
# 602113                  31.0               0                5
# 602114                  21.0               0                5
# 602115                 158.0               0                5
#
#         Total_Harmed_Victims  Suspects_Killed  Suspects_Injured  \
# 0                          6                0                 0
# 1                          6                0                 0
# 2                          6                0                 0
# 3                          6                0                 0
# 4                          6                0                 0
# ...                      ...              ...               ...
# 602111                     5                0                 0
# 602112                     5                0                 0
# 602113                     5                0                 0
# 602114                     5                0                 0
# 602115                     5                0                 0
#
#         Suspects_Arrested  Shootings_State  Shootings_County  Handguns_Sold  \
# 0                       0               30                 3            0.0
# 1                       0               30                 3            0.0
# 2                       0               30                 3            0.0
# 3                       0               30                 3            0.0
# 4                       0               30                 3            0.0
# ...                   ...              ...               ...            ...
# 602111                  2              386                 5        25484.0
# 602112                  2              386                 5        25484.0
# 602113                  2              386                 3        25484.0
# 602114                  2              386                 3        25484.0
# 602115                  2              386                 3        25484.0
#
#         Long_Guns_Sold  Total_Guns_Sold Gun_Law_Strength Gun_Violence_Rate  \
# 0                  0.0              0.0               14                22
# 1                  0.0              0.0               14                22
# 2                  0.0              0.0               14                22
# 3                  0.0              0.0               14                22
# 4                  0.0              0.0               14                22
# ...                ...              ...              ...               ...
# 602111         17575.0          43058.0               14                22
# 602112         17575.0          43058.0               14                22
# 602113         17575.0          43058.0               14                22
# 602114         17575.0          43058.0               14                22
# 602115         17575.0          43058.0               14                22
#
#             Category
# 0       Weak systems
# 1       Weak systems
# 2       Weak systems
# 3       Weak systems
# 4       Weak systems
# ...              ...
# 602111  Weak systems
# 602112  Weak systems
# 602113  Weak systems
# 602114  Weak systems
# 602115  Weak systems
#
# [577567 rows x 27 columns]

# %%
df_merged_final[df_merged_final.isnull().any(axis=1)]
# Out:
#         Incident_ID        Date  Year  Month   Year_Month_State       State  \
# 31          3180141  2025-04-08  2025      4    2025-4-Virginia    Virginia
# 146         3173826  2025-03-31  2025      3       2025-3-Texas       Texas
# 147         3173826  2025-03-31  2025      3       2025-3-Texas       Texas
# 148         3173826  2025-03-31  2025      3       2025-3-Texas       Texas
# 151         3173872  2025-03-30  2025      3  2025-3-California  California
# ...             ...         ...   ...    ...                ...         ...
# 601835       281039  2015-01-19  2015      1       2015-1-Texas       Texas
# 601836       281039  2015-01-19  2015      1       2015-1-Texas       Texas
# 601837       281039  2015-01-19  2015      1       2015-1-Texas       Texas
# 601893       298773  2015-01-13  2015      1    2015-1-Virginia    Virginia
# 601981       276459  2015-01-09  2015      1  2015-1-California  California
#
#                 County            City      Lat      Long  Population  \
# 31      Fredericksburg  Fredericksburg  38.2992  -77.4872         0.0
# 146             Dorado     San Antonio  18.4471  -66.2995         0.0
# 147       Quebradillas     San Antonio  18.4391  -66.9321         0.0
# 148          Aguadilla     San Antonio  18.4932  -67.0997         0.0
# 151      San Francisco   San Francisco  37.7558 -122.4449         0.0
# ...                ...             ...      ...       ...         ...
# 601835          Dorado     San Antonio  18.4471  -66.2995         0.0
# 601836    Quebradillas     San Antonio  18.4391  -66.9321         0.0
# 601837       Aguadilla     San Antonio  18.4932  -67.0997         0.0
# 601893      Portsmouth      Portsmouth  36.8468  -76.3540         0.0
# 601981   San Francisco   San Francisco  37.7558 -122.4449    863237.0
#
#         St_Pop_Density_sqmi  Cty_Pop_Density_sqmi  Victims_Killed  \
# 31                    202.6                   NaN               3
# 146                    96.3                   NaN               0
# 147                    96.3                   NaN               0
# 148                    96.3                   NaN               0
# 151                   239.1                   NaN               0
# ...                     ...                   ...             ...
# 601835                 96.3                   NaN               2
# 601836                 96.3                   NaN               2
# 601837                 96.3                   NaN               2
# 601893                202.6                   NaN               0
# 601981                239.1                   NaN               4
#
#         Victims_Injured  Total_Harmed_Victims  Suspects_Killed  \
# 31                    3                     6                0
# 146                   4                     4                1
# 147                   4                     4                1
# 148                   4                     4                1
# 151                   4                     4                0
# ...                 ...                   ...              ...
# 601835                5                     7                0
# 601836                5                     7                0
# 601837                5                     7                0
# 601893                5                     5                0
# 601981                0                     4                0
#
#         Suspects_Injured  Suspects_Arrested  Shootings_State  \
# 31                     1                  4               17
# 146                    0                  0               56
# 147                    0                  0               56
# 148                    0                  0               56
# 151                    0                  0               14
# ...                  ...                ...              ...
# 601835                 0                  3              289
# 601836                 0                  3              289
# 601837                 0                  3              289
# 601893                 0                  0               95
# 601981                 0                  1              101
#
#         Shootings_County  Handguns_Sold  Long_Guns_Sold  Total_Guns_Sold  \
# 31                     1            0.0             0.0              0.0
# 146                    2            0.0             0.0              0.0
# 147                    2            0.0             0.0              0.0
# 148                    2            0.0             0.0              0.0
# 151                    1            0.0             0.0              0.0
# ...                  ...            ...             ...              ...
# 601835                 2        51105.0         42573.0          93678.0
# 601836                 2        51105.0         42573.0          93678.0
# 601837                 2        51105.0         42573.0          93678.0
# 601893                 1        23125.0         15876.0          39002.0
# 601981                 1        41316.0         25876.0          67192.0
#
#        Gun_Law_Strength Gun_Violence_Rate         Category
# 31                   49              13,8  Making progress
# 146                13,5              14,9     Weak systems
# 147                13,5              14,9     Weak systems
# 148                13,5              14,9     Weak systems
# 151                90,5                 8  National leader
# ...                 ...               ...              ...
# 601835             13,5              14,9     Weak systems
# 601836             13,5              14,9     Weak systems
# 601837             13,5              14,9     Weak systems
# 601893               49              13,8  Making progress
# 601981             90,5                 8  National leader
#
# [14759 rows x 27 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
df_merged_final.isnull().sum()
# Out:
# Incident_ID                 0
# Date                        0
# Year                        0
# Month                       0
# Year_Month_State            0
# State                       0
# County                      0
# City                        0
# Lat                         0
# Long                        0
# Population                  0
# St_Pop_Density_sqmi     13467
# Cty_Pop_Density_sqmi     1493
# Victims_Killed              0
# Victims_Injured             0
# Total_Harmed_Victims        0
# Suspects_Killed             0
# Suspects_Injured            0
# Suspects_Arrested           0
# Shootings_State             0
# Shootings_County            0
# Handguns_Sold               0
# Long_Guns_Sold              0
# Total_Guns_Sold             0
# Gun_Law_Strength        13467
# Gun_Violence_Rate       13467
# Category                13467
# dtype: int64

# %%
#Replacing NaN with 0: NaNs in this case are due to nonexistent records. 
df_merged_final = df_merged_final.fillna(0)

# %%
df_merged_final.isnull().sum()
# Out:
# Incident_ID             0
# Date                    0
# Year                    0
# Month                   0
# Year_Month_State        0
# State                   0
# County                  0
# City                    0
# Lat                     0
# Long                    0
# Population              0
# St_Pop_Density_sqmi     0
# Cty_Pop_Density_sqmi    0
# Victims_Killed          0
# Victims_Injured         0
# Total_Harmed_Victims    0
# Suspects_Killed         0
# Suspects_Injured        0
# Suspects_Arrested       0
# Shootings_State         0
# Shootings_County        0
# Handguns_Sold           0
# Long_Guns_Sold          0
# Total_Guns_Sold         0
# Gun_Law_Strength        0
# Gun_Violence_Rate       0
# Category                0
# dtype: int64

# %%
df_final = df_merged_final

# %%
df_final
# Out:
#         Incident_ID        Date  Year  Month  Year_Month_State      State  \
# 0           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 1           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 2           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 3           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# 4           3181158  2025-04-09  2025      4  2025-4-Tennessee  Tennessee
# ...             ...         ...   ...    ...               ...        ...
# 602111       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602112       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602113       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602114       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
# 602115       272016  2015-01-01  2015      1  2015-1-Tennessee  Tennessee
#
#           County     City      Lat     Long  Population  St_Pop_Density_sqmi  \
# 0         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 1         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 2         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 3         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# 4         Shelby  Memphis  35.1087 -89.9663         0.0                153.9
# ...          ...      ...      ...      ...         ...                  ...
# 602111     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602112     Clark  Memphis  38.4891 -85.7679         0.0                153.9
# 602113  Saunders  Memphis  41.0946 -96.4332         0.0                153.9
# 602114   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
# 602115   Pickens  Memphis  33.1369 -88.3008         0.0                153.9
#
#         Cty_Pop_Density_sqmi  Victims_Killed  Victims_Injured  \
# 0                      301.0               1                5
# 1                       27.0               1                5
# 2                      111.0               1                5
# 3                       20.0               1                5
# 4                      131.0               1                5
# ...                      ...             ...              ...
# 602111               47934.0               0                5
# 602112                  29.0               0                5
# 602113                  31.0               0                5
# 602114                  21.0               0                5
# 602115                 158.0               0                5
#
#         Total_Harmed_Victims  Suspects_Killed  Suspects_Injured  \
# 0                          6                0                 0
# 1                          6                0                 0
# 2                          6                0                 0
# 3                          6                0                 0
# 4                          6                0                 0
# ...                      ...              ...               ...
# 602111                     5                0                 0
# 602112                     5                0                 0
# 602113                     5                0                 0
# 602114                     5                0                 0
# 602115                     5                0                 0
#
#         Suspects_Arrested  Shootings_State  Shootings_County  Handguns_Sold  \
# 0                       0               30                 3            0.0
# 1                       0               30                 3            0.0
# 2                       0               30                 3            0.0
# 3                       0               30                 3            0.0
# 4                       0               30                 3            0.0
# ...                   ...              ...               ...            ...
# 602111                  2              386                 5        25484.0
# 602112                  2              386                 5        25484.0
# 602113                  2              386                 3        25484.0
# 602114                  2              386                 3        25484.0
# 602115                  2              386                 3        25484.0
#
#         Long_Guns_Sold  Total_Guns_Sold Gun_Law_Strength Gun_Violence_Rate  \
# 0                  0.0              0.0               14                22
# 1                  0.0              0.0               14                22
# 2                  0.0              0.0               14                22
# 3                  0.0              0.0               14                22
# 4                  0.0              0.0               14                22
# ...                ...              ...              ...               ...
# 602111         17575.0          43058.0               14                22
# 602112         17575.0          43058.0               14                22
# 602113         17575.0          43058.0               14                22
# 602114         17575.0          43058.0               14                22
# 602115         17575.0          43058.0               14                22
#
#             Category
# 0       Weak systems
# 1       Weak systems
# 2       Weak systems
# 3       Weak systems
# 4       Weak systems
# ...              ...
# 602111  Weak systems
# 602112  Weak systems
# 602113  Weak systems
# 602114  Weak systems
# 602115  Weak systems
#
# [577567 rows x 27 columns]

# %%
dup = df_final.duplicated()
dup.sum()
# Out:
# 0

# %%
df_final.isnull().sum()
# Out:
# Incident_ID             0
# Date                    0
# Year                    0
# Month                   0
# Year_Month_State        0
# State                   0
# County                  0
# City                    0
# Lat                     0
# Long                    0
# Population              0
# St_Pop_Density_sqmi     0
# Cty_Pop_Density_sqmi    0
# Victims_Killed          0
# Victims_Injured         0
# Total_Harmed_Victims    0
# Suspects_Killed         0
# Suspects_Injured        0
# Suspects_Arrested       0
# Shootings_State         0
# Shootings_County        0
# Handguns_Sold           0
# Long_Guns_Sold          0
# Total_Guns_Sold         0
# Gun_Law_Strength        0
# Gun_Violence_Rate       0
# Category                0
# dtype: int64

# %% [markdown]
# #### Exporting frame

# %%
df_final.to_csv(os.path.join(path, '02_Data', 'Prepared', '150425_finalproject_2.csv'))

# %% [markdown]
# #### 4. Exploratory analysis

# %%
df_final.describe()
# Out:
#         Incident_ID           Year          Month            Lat  \
# count  5.775670e+05  577567.000000  577567.000000  577567.000000
# mean   2.293309e+06    2021.809828       6.624535      38.520081
# std    5.998540e+05       2.030511       3.020515       3.768586
# min    2.720160e+05    2015.000000       1.000000      17.977800
# 25%    1.793559e+06    2020.000000       4.000000      35.949000
# 50%    2.423331e+06    2022.000000       7.000000      39.044800
# 75%    2.737798e+06    2023.000000       9.000000      40.576600
# max    3.181158e+06    2025.000000      12.000000      68.344500
#
#                 Long    Population  St_Pop_Density_sqmi  Cty_Pop_Density_sqmi  \
# count  577567.000000  5.775670e+05        577567.000000         577567.000000
# mean      -89.442507  1.190317e+05           161.358477            278.341495
# std         9.886973  5.856961e+05           133.274546           1740.351146
# min      -170.274300  0.000000e+00             0.000000              0.000000
# 25%       -94.145100  1.094500e+04            87.100000             24.000000
# 50%       -87.686600  2.718200e+04           109.900000             55.000000
# 75%       -82.985500  6.434100e+04           202.600000            161.000000
# max       -65.773300  3.129083e+07          1195.500000          70915.000000
#
#        Victims_Killed  Victims_Injured  Total_Harmed_Victims  Suspects_Killed  \
# count   577567.000000    577567.000000         577567.000000    577567.000000
# mean         0.974309         4.158518              5.132828         0.071072
# std          1.231360         3.218048              3.399231         0.263158
# min          0.000000         0.000000              0.000000         0.000000
# 25%          0.000000         3.000000              4.000000         0.000000
# 50%          1.000000         4.000000              4.000000         0.000000
# 75%          1.000000         5.000000              5.000000         0.000000
# max         60.000000       439.000000            499.000000         3.000000
#
#        Suspects_Injured  Suspects_Arrested  Shootings_State  Shootings_County  \
# count     577567.000000      577567.000000    577567.000000     577567.000000
# mean           0.048349           0.719018       531.901327        116.764857
# std            0.235878           1.129136       328.231340        118.250978
# min            0.000000           0.000000         1.000000          1.000000
# 25%            0.000000           0.000000       267.000000         24.000000
# 50%            0.000000           0.000000       497.000000         72.000000
# 75%            0.000000           1.000000       712.000000        180.000000
# max            5.000000          14.000000      1303.000000        483.000000
#
#        Handguns_Sold  Long_Guns_Sold  Total_Guns_Sold
# count   577567.00000   577567.000000    577567.000000
# mean     29717.49949    18222.764919     47940.245166
# std      24361.01782    12213.802803     35541.889313
# min          0.00000        0.000000         0.000000
# 25%      11663.00000    10337.000000     22170.000000
# 50%      23205.00000    15336.000000     37650.000000
# 75%      36602.00000    22864.000000     60215.000000
# max     171600.00000   102546.000000    248724.000000

# %%
df_final.dtypes
# Out:
# Incident_ID               int64
# Date                     object
# Year                      int64
# Month                     int64
# Year_Month_State         object
# State                    object
# County                   object
# City                     object
# Lat                     float64
# Long                    float64
# Population              float64
# St_Pop_Density_sqmi     float64
# Cty_Pop_Density_sqmi    float64
# Victims_Killed            int64
# Victims_Injured           int64
# Total_Harmed_Victims      int64
# Suspects_Killed           int64
# Suspects_Injured          int64
# Suspects_Arrested         int64
# Shootings_State           int64
# Shootings_County          int64
# Handguns_Sold           float64
# Long_Guns_Sold          float64
# Total_Guns_Sold         float64
# Gun_Law_Strength         object
# Gun_Violence_Rate        object
# Category                 object
# dtype: object

# %% [markdown]
# #### Splitting notebook

# %% [markdown]
# Next section is in a different file
