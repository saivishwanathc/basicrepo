# %% [markdown]
# 1. Importing libraries

# %%
import pandas as pd
import numpy as np
import os 
import pickle

# %% [markdown]
# 2. Importing datasets

# %%
path = r'C:/Users/C SaiVishwanath/Documents/CF/Data Immersion/Achievement 6'

# %%
pop20 = pd.read_csv(os.path.join(path, '02_Data', 'Original', 'US Population 2010-2020.csv'), sep=';', index_col = False, encoding='latin1')
pop24 = pd.read_csv(os.path.join(path, '02_Data', 'Original', 'US Population 2020-2024.csv'), sep=';', index_col = False, encoding='latin1')

# %%
pop20
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3189      50       4         8     56      37  Wyoming  Sweetwater County
# 3190      50       4         8     56      39  Wyoming       Teton County
# 3191      50       4         8     56      41  Wyoming       Uinta County
# 3192      50       4         8     56      43  Wyoming    Washakie County
# 3193      50       4         8     56      45  Wyoming      Weston County
#
#      CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# ...

# %%
pop24
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3190      50       4         8     56      37  Wyoming  Sweetwater County
# 3191      50       4         8     56      39  Wyoming       Teton County
# 3192      50       4         8     56      41  Wyoming       Uinta County
# 3193      50       4         8     56      43  Wyoming    Washakie County
# 3194      50       4         8     56      45  Wyoming      Weston County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  \
# ...

# %% [markdown]
# 2. Null values

# %%
# Count non-null data points per column
count_per_column = pop20.count()

print(count_per_column)
# Out:
# SUMLEV               3194
# REGION               3194
# DIVISION             3194
# STATE                3194
# COUNTY               3194
# STNAME               3194
# CTYNAME              3194
# CENSUS2010POP        3194
# ESTIMATESBASE2010    3194
# POPESTIMATE2010      3194
# POPESTIMATE2011      3194
# POPESTIMATE2012      3194
# POPESTIMATE2013      3194
# POPESTIMATE2014      3194
# POPESTIMATE2015      3194
# POPESTIMATE2016      3194
# POPESTIMATE2017      3194
# POPESTIMATE2018      3194
# POPESTIMATE2019      3194
# POPESTIMATE2020      3194
# dtype: int64

# %%
count_per_column = pop24.count()

print(count_per_column)
# Out:
# SUMLEV               3195
# REGION               3195
# DIVISION             3195
# STATE                3195
# COUNTY               3195
# STNAME               3195
# CTYNAME              3195
# ESTIMATESBASE2020    3195
# POPESTIMATE2020      3195
# POPESTIMATE2021      3195
# POPESTIMATE2022      3195
# POPESTIMATE2023      3195
# POPESTIMATE2024      3195
# dtype: int64

# %%
#Count of null values
pop20.isnull().sum()
# Out:
# SUMLEV               0
# REGION               0
# DIVISION             0
# STATE                0
# COUNTY               0
# STNAME               0
# CTYNAME              0
# CENSUS2010POP        0
# ESTIMATESBASE2010    0
# POPESTIMATE2010      0
# POPESTIMATE2011      0
# POPESTIMATE2012      0
# POPESTIMATE2013      0
# POPESTIMATE2014      0
# POPESTIMATE2015      0
# POPESTIMATE2016      0
# POPESTIMATE2017      0
# POPESTIMATE2018      0
# POPESTIMATE2019      0
# POPESTIMATE2020      0
# dtype: int64

# %%
pop24.isnull().sum()
# Out:
# SUMLEV               0
# REGION               0
# DIVISION             0
# STATE                0
# COUNTY               0
# STNAME               0
# CTYNAME              0
# ESTIMATESBASE2020    0
# POPESTIMATE2020      0
# POPESTIMATE2021      0
# POPESTIMATE2022      0
# POPESTIMATE2023      0
# POPESTIMATE2024      0
# dtype: int64

# %% [markdown]
# 3. Duplicates

# %%
#Checking in pop20
pop20_dups = pop20[pop20.duplicated()]

# %%
pop20_dups
# Out:
# Empty DataFrame
# Columns: [SUMLEV, REGION, DIVISION, STATE, COUNTY, STNAME, CTYNAME, CENSUS2010POP, ESTIMATESBASE2010, POPESTIMATE2010, POPESTIMATE2011, POPESTIMATE2012, POPESTIMATE2013, POPESTIMATE2014, POPESTIMATE2015, POPESTIMATE2016, POPESTIMATE2017, POPESTIMATE2018, POPESTIMATE2019, POPESTIMATE2020]
# Index: []

# %%
#Checking in pop 24/
pop24_dups = pop24[pop24.duplicated()]

# %%
pop24_dups
# Out:
# Empty DataFrame
# Columns: [SUMLEV, REGION, DIVISION, STATE, COUNTY, STNAME, CTYNAME, ESTIMATESBASE2020, POPESTIMATE2020, POPESTIMATE2021, POPESTIMATE2022, POPESTIMATE2023, POPESTIMATE2024]
# Index: []

# %% [markdown]
# 4. Mixed type columns

# %%
#Checking in pop20
for col in pop20.columns.tolist():
    weird = (pop20[[col]].applymap(type) != pop20
[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (pop20[weird]) > 0:
        print (col)
# Out:
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\26685550.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (pop20[[col]].applymap(type) != pop20
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\26685550.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (pop20[[col]].applymap(type) != pop20
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\26685550.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (pop20[[col]].applymap(type) != pop20
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\26685550.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (pop20[[col]].applymap(type) != pop20
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\26685550.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
#Checking in pop24
for col in pop24.columns.tolist():
    weird = (pop24[[col]].applymap(type) != pop24
[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (pop24[weird]) > 0:
        print (col)
# Out:
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\4260323405.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (pop24[[col]].applymap(type) != pop24
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\4260323405.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (pop24[[col]].applymap(type) != pop24
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\4260323405.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (pop24[[col]].applymap(type) != pop24
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\4260323405.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (pop24[[col]].applymap(type) != pop24
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_27652\4260323405.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %% [markdown]
# 5. Frequencies

# %%
#Print pop20
# Loop through all columns and print frequencies
for col in pop20.columns:
    print(f"\n--- Column: {col} ---")
    print(pop20[col].value_counts(dropna=False))
    print(f"Grand total (including NaNs): {pop20[col].size}")
# Out:
# --- Column: SUMLEV ---
# SUMLEV
# 50    3143
# 40      51
# Name: count, dtype: int64
# Grand total (including NaNs): 3194
#
# --- Column: REGION ---
# REGION
# 3    1439
# 2    1067
# 4     462
# 1     226
# Name: count, dtype: int64
# Grand total (including NaNs): 3194
#
# --- Column: DIVISION ---
# DIVISION
# 4    625
# 5    597
# 7    474
# 3    442
# 6    368
# 8    289
# 9    173
# 2    153
# 1     73
# Name: count, dtype: int64
# Grand total (including NaNs): 3194
#
# --- Column: STATE ---
# STATE
# 48    255
# 13    160
# 51    134
# 21    121
# 29    116
# 20    106
# 17    103
# 37    101
# 19    100
# 47     96
# 31     94
# 18     93
# 39     89
# 27     88
# 26     84
# 28     83
# 40     78
# 5      76
# 55     73
# 42     68
# 1      68
# 12     68
# 46     67
# 8      65
# 22     65
# 36     63
# 6      59
# 30     57
# 54     56
# 38     54
# 45     47
# 16     45
# 53     40
# 41     37
# 35     34
# 2      31
# 49     30
# 24     25
# 56     24
# 34     22
# ...

# %%
#Print pop24
# Loop through all columns and print frequencies
for col in pop24.columns:
    print(f"\n--- Column: {col} ---")
    print(pop24[col].value_counts(dropna=False))
    print(f"Grand total (including NaNs): {pop24[col].size}")
# Out:
# --- Column: SUMLEV ---
# SUMLEV
# 50    3144
# 40      51
# Name: count, dtype: int64
# Grand total (including NaNs): 3195
#
# --- Column: REGION ---
# REGION
# 3    1439
# 2    1067
# 4     462
# 1     227
# Name: count, dtype: int64
# Grand total (including NaNs): 3195
#
# --- Column: DIVISION ---
# DIVISION
# 4    625
# 5    597
# 7    474
# 3    442
# 6    368
# 8    289
# 9    173
# 2    153
# 1     74
# Name: count, dtype: int64
# Grand total (including NaNs): 3195
#
# --- Column: STATE ---
# STATE
# 48    255
# 13    160
# 51    134
# 21    121
# 29    116
# 20    106
# 17    103
# 37    101
# 19    100
# 47     96
# 31     94
# 18     93
# 39     89
# 27     88
# 26     84
# 28     83
# 40     78
# 5      76
# 55     73
# 42     68
# 1      68
# 12     68
# 46     67
# 8      65
# 22     65
# 36     63
# 6      59
# 30     57
# 54     56
# 38     54
# 45     47
# 16     45
# 53     40
# 41     37
# 35     34
# 2      31
# 49     30
# 24     25
# 56     24
# 34     22
# ...

# %%
#End of consistency check. No inconsistencies found. No need to export.
