# %% [markdown]
# 1. Importing libraries

# %%
import pandas as pd
import numpy as np
import os 
import pickle

# %% [markdown]
# 2. Importing datasets

# %%
path = r'C:/Users/C SaiVishwanath/Documents/CF/Data Immersion/Achievement 6'

# %%
df_pop20 = pd.read_csv(os.path.join(path, '02_Data', 'Original', 'US Population 2010-2020.csv'), sep=';', index_col = False, encoding='latin1')
df_pop24 = pd.read_csv(os.path.join(path, '02_Data', 'Original', 'US Population 2020-2024.csv'), sep=';', index_col = False, encoding='latin1')

# %%
df_pop20
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3189      50       4         8     56      37  Wyoming  Sweetwater County
# 3190      50       4         8     56      39  Wyoming       Teton County
# 3191      50       4         8     56      41  Wyoming       Uinta County
# 3192      50       4         8     56      43  Wyoming    Washakie County
# 3193      50       4         8     56      45  Wyoming      Weston County
#
#      CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# ...

# %%
df_pop24
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3190      50       4         8     56      37  Wyoming  Sweetwater County
# 3191      50       4         8     56      39  Wyoming       Teton County
# 3192      50       4         8     56      41  Wyoming       Uinta County
# 3193      50       4         8     56      43  Wyoming    Washakie County
# 3194      50       4         8     56      45  Wyoming      Weston County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  \
# ...

# %% [markdown]
# 3. Dropping and renaming columns on pop20

# %%
#Dropping in pop20
df_pop20_wrangled = pop20.drop(columns=['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 
                        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010', 
                        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2020'
                ])

# %%
df_pop20_wrangled
# Out:
#        STNAME            CTYNAME  POPESTIMATE2015  POPESTIMATE2016  \
# 0     Alabama            Alabama          4854803          4866824
# 1     Alabama     Autauga County            54903            55302
# 2     Alabama     Baldwin County           203101           207787
# 3     Alabama     Barbour County            26300            25828
# 4     Alabama        Bibb County            22553            22590
# ...       ...                ...              ...              ...
# 3189  Wyoming  Sweetwater County            44780            44319
# 3190  Wyoming       Teton County            23083            23255
# 3191  Wyoming       Uinta County            20777            20711
# 3192  Wyoming    Washakie County             8282             8180
# 3193  Wyoming      Weston County             7202             7228
#
#       POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019
# 0             4877989          4891628          4907965
# ...

# %%
#Renaming in pop20_wrangled
df_pop20_wrangled2 = df_pop20_wrangled.rename(columns = {
    'STNAME': 'State',
    'CTYNAME': 'County',
    'POPESTIMATE2015': 'Pop2015',
    'POPESTIMATE2016': 'Pop2016',
    'POPESTIMATE2017': 'Pop2017',
    'POPESTIMATE2018': 'Pop2018',
    'POPESTIMATE2019': 'Pop2019',
})

# %%
df_pop20_wrangled2
# Out:
#         State             County  Pop2015  Pop2016  Pop2017  Pop2018  Pop2019
# 0     Alabama            Alabama  4854803  4866824  4877989  4891628  4907965
# 1     Alabama     Autauga County    54903    55302    55448    55533    55769
# 2     Alabama     Baldwin County   203101   207787   212737   218071   223565
# 3     Alabama     Barbour County    26300    25828    25169    24887    24657
# 4     Alabama        Bibb County    22553    22590    22532    22300    22313
# ...       ...                ...      ...      ...      ...      ...      ...
# 3189  Wyoming  Sweetwater County    44780    44319    43663    43188    42917
# 3190  Wyoming       Teton County    23083    23255    23383    23261    23385
# 3191  Wyoming       Uinta County    20777    20711    20449    20299    20196
# 3192  Wyoming    Washakie County     8282     8180     8013     7886     7824
# 3193  Wyoming      Weston County     7202     7228     6962     6895     6880
#
# [3194 rows x 7 columns]

# %% [markdown]
# 4. Dropping and renaming columns on pop24

# %%
df_pop24
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3190      50       4         8     56      37  Wyoming  Sweetwater County
# 3191      50       4         8     56      39  Wyoming       Teton County
# 3192      50       4         8     56      41  Wyoming       Uinta County
# 3193      50       4         8     56      43  Wyoming    Washakie County
# 3194      50       4         8     56      45  Wyoming      Weston County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  \
# ...

# %%
#Dropping in pop24
df_pop24_wrangled = pop24.drop(columns=['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 
                        'ESTIMATESBASE2020'
                ])

# %%
df_pop24_wrangled
# Out:
#        STNAME            CTYNAME  POPESTIMATE2020  POPESTIMATE2021  \
# 0     Alabama            Alabama          5033094          5049196
# 1     Alabama     Autauga County            58909            59191
# 2     Alabama     Baldwin County           233244           239411
# 3     Alabama     Barbour County            24975            24517
# 4     Alabama        Bibb County            22176            22344
# ...       ...                ...              ...              ...
# 3190  Wyoming  Sweetwater County            42196            41630
# 3191  Wyoming       Teton County            23384            23613
# 3192  Wyoming       Uinta County            20461            20690
# 3193  Wyoming    Washakie County             7663             7727
# 3194  Wyoming      Weston County             6817             6747
#
#       POPESTIMATE2022  POPESTIMATE2023  POPESTIMATE2024
# 0             5076181          5117673          5157699
# ...

# %%
#Renaming in pop24
#Renaming in pop20_wrangled
df_pop24_wrangled2 = df_pop24_wrangled.rename(columns = {
    'STNAME': 'State',
    'CTYNAME': 'County',
    'POPESTIMATE2020': 'Pop2020',
    'POPESTIMATE2021': 'Pop2021',
    'POPESTIMATE2022': 'Pop2022',
    'POPESTIMATE2023': 'Pop2023',
    'POPESTIMATE2024': 'Pop2024',
})

# %%
df_pop24_wrangled2
# Out:
#         State             County  Pop2020  Pop2021  Pop2022  Pop2023  Pop2024
# 0     Alabama            Alabama  5033094  5049196  5076181  5117673  5157699
# 1     Alabama     Autauga County    58909    59191    59736    60436    61464
# 2     Alabama     Baldwin County   233244   239411   246577   254107   261608
# 3     Alabama     Barbour County    24975    24517    24722    24644    24358
# 4     Alabama        Bibb County    22176    22344    21983    21890    22258
# ...       ...                ...      ...      ...      ...      ...      ...
# 3190  Wyoming  Sweetwater County    42196    41630    41322    41288    41273
# 3191  Wyoming       Teton County    23384    23613    23341    23368    23272
# 3192  Wyoming       Uinta County    20461    20690    20722    20724    20621
# 3193  Wyoming    Washakie County     7663     7727     7728     7736     7662
# 3194  Wyoming      Weston County     6817     6747     6872     6828     6866
#
# [3195 rows x 7 columns]

# %% [markdown]
# 5. Merging population

# %%
# Merge datasets: Mass shootings and Gun sales data 
pop_merged = pd.merge(df_pop20_wrangled2, df_pop24_wrangled2, on='County', how='outer')

# %%
pop_merged
# Out:
#               State_x            County   Pop2015   Pop2016   Pop2017  \
# 0      South Carolina  Abbeville County   24814.0   24688.0   24598.0
# 1           Louisiana     Acadia Parish   62696.0   62830.0   62581.0
# 2            Virginia   Accomack County   32930.0   32903.0   32729.0
# 3               Idaho        Ada County  433254.0  444929.0  456994.0
# 4                Iowa      Adair County    7142.0    7006.0    7047.0
# ...               ...               ...       ...       ...       ...
# 14583        Colorado       Yuma County   10044.0   10057.0    9976.0
# 14584        Colorado       Yuma County   10044.0   10057.0    9976.0
# 14585           Texas     Zapata County   14474.0   14420.0   14251.0
# 14586           Texas     Zavala County   12322.0   12125.0   11946.0
# 14587    South Dakota    Ziebach County    2838.0    2870.0    2747.0
#
#         Pop2018   Pop2019         State_y   Pop2020   Pop2021   Pop2022  \
# ...

# %% [markdown]
# 6. Consistency checks

# %%
#Null values
pop_merged.isnull().sum()
# Out:
# State_x    9
# County     0
# Pop2015    9
# Pop2016    9
# Pop2017    9
# Pop2018    9
# Pop2019    9
# State_y    5
# Pop2020    5
# Pop2021    5
# Pop2022    5
# Pop2023    5
# Pop2024    5
# dtype: int64

# %%
# Count non-null data points per column
count_per_column = pop_merged.count()

print(count_per_column)
# Out:
# State_x    14579
# County     14588
# Pop2015    14579
# Pop2016    14579
# Pop2017    14579
# Pop2018    14579
# Pop2019    14579
# State_y    14583
# Pop2020    14583
# Pop2021    14583
# Pop2022    14583
# Pop2023    14583
# Pop2024    14583
# dtype: int64

# %%
#Inspecting null values
pop_merged_nulls = pop_merged[pop_merged.isnull().any(axis=1)]

# %%
pop_merged_nulls.shape
# Out:
# (14, 13)

# %%
pop_merged_nulls
# Out:
#            State_x                                          County   Pop2015  \
# 1087           NaN                         Capitol Planning Region       NaN
# 4389           NaN              Greater Bridgeport Planning Region       NaN
# 5001   Connecticut                                 Hartford County  896563.0
# 8144   Connecticut                               Litchfield County  184171.0
# 8289           NaN  Lower Connecticut River Valley Planning Region       NaN
# 10352          NaN                Naugatuck Valley Planning Region       NaN
# 10380  Connecticut                                New Haven County  860506.0
# 10383  Connecticut                               New London County  269818.0
# 10464          NaN        Northeastern Connecticut Planning Region       NaN
# 10470          NaN                 Northwest Hills Planning Region       NaN
# 12105          NaN       South Central Connecticut Planning Region       NaN
# ...

# %%
#Dropping values
pop_merged_clean = pop_merged.dropna()

# %%
pop_merged_clean.isnull().sum()
# Out:
# State_x    0
# County     0
# Pop2015    0
# Pop2016    0
# Pop2017    0
# Pop2018    0
# Pop2019    0
# State_y    0
# Pop2020    0
# Pop2021    0
# Pop2022    0
# Pop2023    0
# Pop2024    0
# dtype: int64

# %%
#Checking duplicates
pop_merged_clean[pop_merged_clean.duplicated()]
# Out:
#                    State_x                County   Pop2015   Pop2016  \
# 2842  District of Columbia  District of Columbia  677014.0  687576.0
# 2843  District of Columbia  District of Columbia  677014.0  687576.0
# 2844  District of Columbia  District of Columbia  677014.0  687576.0
#
#        Pop2017   Pop2018   Pop2019               State_y   Pop2020   Pop2021  \
# 2842  697079.0  704147.0  708253.0  District of Columbia  670917.0  669256.0
# 2843  697079.0  704147.0  708253.0  District of Columbia  670917.0  669256.0
# 2844  697079.0  704147.0  708253.0  District of Columbia  670917.0  669256.0
#
#        Pop2022   Pop2023   Pop2024
# 2842  676725.0  687324.0  702250.0
# 2843  676725.0  687324.0  702250.0
# 2844  676725.0  687324.0  702250.0

# %%
#Dropping duplicates
pop_merged_clean2 = pop_merged_clean.drop_duplicates()

# %%
pop_merged_clean2[pop_merged_clean2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [State_x, County, Pop2015, Pop2016, Pop2017, Pop2018, Pop2019, State_y, Pop2020, Pop2021, Pop2022, Pop2023, Pop2024]
# Index: []

# %%
pop_merged_clean2.isnull().sum()
# Out:
# State_x    0
# County     0
# Pop2015    0
# Pop2016    0
# Pop2017    0
# Pop2018    0
# Pop2019    0
# State_y    0
# Pop2020    0
# Pop2021    0
# Pop2022    0
# Pop2023    0
# Pop2024    0
# dtype: int64

# %% [markdown]
# 7. Wrangling and renaming

# %%
#Dropping unnecessary/duplicate columns
pop_merged_clean2 = pop_merged_clean2.drop(columns=['State_y'
                ])

# %%
#Renaming columns
pop_merged_clean2 = pop_merged_clean2.rename(columns = {
    'State_x': 'State',
    })

# %%
pop_merged_clean2
# Out:
#                 State            County   Pop2015   Pop2016   Pop2017  \
# 0      South Carolina  Abbeville County   24814.0   24688.0   24598.0
# 1           Louisiana     Acadia Parish   62696.0   62830.0   62581.0
# 2            Virginia   Accomack County   32930.0   32903.0   32729.0
# 3               Idaho        Ada County  433254.0  444929.0  456994.0
# 4                Iowa      Adair County    7142.0    7006.0    7047.0
# ...               ...               ...       ...       ...       ...
# 14583        Colorado       Yuma County   10044.0   10057.0    9976.0
# 14584        Colorado       Yuma County   10044.0   10057.0    9976.0
# 14585           Texas     Zapata County   14474.0   14420.0   14251.0
# 14586           Texas     Zavala County   12322.0   12125.0   11946.0
# 14587    South Dakota    Ziebach County    2838.0    2870.0    2747.0
#
#         Pop2018   Pop2019   Pop2020   Pop2021   Pop2022   Pop2023   Pop2024
# ...

# %% [markdown]
# 8. Exporting clean and wrangled dataset

# %%
pop_merged_clean2.to_csv(os.path.join(path, '02_Data', 'Prepared', 'population2015-2020.csv'))
